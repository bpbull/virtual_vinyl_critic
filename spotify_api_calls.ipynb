# %%
import pandas as pd
import time
from tqdm import tqdm
import pickle
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

# %% [markdown]
# # Spotify Data Collection

# %% [markdown]
# ## 1. Establish credentials

# %%
#spotify API credentials

CLIENT_ID = "my_client_id"
CLIENT_SECRET = "my_client_secret"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
sp = spotipy.Spotify(auth=token)

# %% [markdown]
# ## 2. Import and format data from Pitchfork

# %%
#import dataframe from pitchfork web scraping
pitchfork_df = pd.read_pickle('pitchfork_df.pickle')

# %%
pitchfork_df.head()
# Out:
#                          Album           Artist Score       Genres  \
# 0             Petals for Armor  Hayley Williams   7.2  Pop/R&BRock
# 1                      Regresa       Buscabulla   7.7   Electronic
# 2          What’s New, Tomboy?    Damien Jurado   7.3         Rock
# 3                  Shadow Talk       Cafe Racer   7.4         Rock
# 4  It Was Good Until It Wasn’t          Kehlani   7.7      Pop/R&B
#
#                                              Summary
# 0  The Paramore singer’s debut solo album is emot...
# 1  The Puerto Rican duo moved back to the island ...
# 2  Channeling stripped-back pop songs into hushed...
# 3  The Chicago band’s third album brings wiry new...
# 4  The cloudy grooves of the Oakland singer’s sec...

# %%
#creat list of lists for album-artist pairs in order to search spotify
alb_art_pairs = [[pitchfork_df.Album[x], pitchfork_df.Artist[x]] for x in range(len(pitchfork_df))]

# %%
len(alb_art_pairs)
# Out:
# 6516

# %%
alb_art_pairs[0:5]
# Out:
# [['Petals for Armor', 'Hayley Williams'],
#  ['Regresa', 'Buscabulla'],
#  ['What’s New, Tomboy?', 'Damien Jurado'],
#  ['Shadow Talk', 'Cafe Racer'],
#  ['It Was Good Until It Wasn’t', 'Kehlani']]

# %% [markdown]
# ## 3. Gather Spotify data about albums

# %%
#function for getting spotify album ID's from album name and artist pair
def GetAlbumID(album, artist):
    results = sp.search(q = "album:" + album + ' artist:' + artist, type = "album")
    return results['albums']['items'][0]['uri']

# %%
#test function
a = GetAlbumID('A Moon Shaped Pool', "Radiohead")
a
# Out:
# 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'

# %%
album_IDs2_combo = []
album_IDs2 = []

# %%
#loop through every pair of artist-album to get the spotify albums ID
for pair in tqdm(alb_art_pairs):
    time.sleep(1)
    try:
        album_IDs2_combo.append([GetAlbumID(pair[0],pair[1]),pair[0],pair[1]])
        album_IDs2.append([GetAlbumID(pair[0],pair[1])])
    except:
        album_IDs2_combo.append(['Spotify features Not found',pair[0],pair[1]])
        album_IDs2.append(['Spotify features Not found'])

# %%
#function for getting the track ID's for all of the songs in an album
def GetTrackIDs(album_id):
    track_id_list = []
    track_ids = sp.album_tracks(album_id)
    for track in track_ids['items']:
        track_id_list.append(track['id'])
    return track_id_list

# %%
#test function
c = GetTrackIDs(a)
c
# Out:
# ['3pcCifdPTc2BbqmWpEhtUd',
#  '1uRxyAup7OYrlh2SHJb80N',
#  '5rIhBK9aaVMck0W2YtOwci',
#  '1kBGeOp1CDUHVdbK4ergqo',
#  '4CzTgOmc3Sdm4EgKQWzjQl',
#  '0eZN5WsQfmNFICHuw59Zfz',
#  '3LhtqibvTtjOUrzKs7Vsz1',
#  '6f6pEjgfTtuRROmJ4a7Gf3',
#  '4eruRiSfDY1jdT03hjyi0i',
#  '3cual6JOG286qZJmCxKRAT',
#  '01ZpFhrMMqKPVCwyqXneVp']

# %%
#create lists to append song ids and their respective album
song_ids_album2 = []
song_ids2 = []

# %%
#get spotify ID's for all of the tracks in all albums
for album in tqdm(album_IDs2):
    for alb in album:
        time.sleep(1)
        try:
            song_ids_album2.append([GetTrackIDs(alb),alb])
            song_ids2.append([GetTrackIDs(alb)])
        except:
            song_ids_album2.append(['Spotify features Not found',alb])
            song_ids2.append(['Spotify features Not found'])

# %%
#save the song ids
with open('song_ids.pkl', 'wb') as f:
    pickle.dump(song_ids2, f)

# %% [markdown]
# ## 4. Get Spotify data about songs

# %%
#function for getting information for a list of songs from song IDs
def GetTrackDescription(track_ids):
    track_descriptions = []
    for track_id in track_ids:
        description = sp.track(track_id)
        track_descriptions.append(description)
    return track_descriptions

# %%
#test function
d = GetTrackDescription(c)
d

# %%
#function for getting audio features for a list of tracks
def GetTrackInfo(track_ids):
    tracks_info = []
    for track_id in track_ids:
        info = sp.audio_features(track_id)
        tracks_info.append(info)
    return tracks_info

# %%
#test function
e = GetTrackInfo(c)
e
# Out:
# [[{'danceability': 0.541,
#    'energy': 0.847,
#    'key': 11,
#    'loudness': -6.52,
#    'mode': 1,
#    'speechiness': 0.0297,
#    'acousticness': 0.303,
#    'instrumentalness': 0.271,
#    'liveness': 0.109,
#    'valence': 0.62,
#    'tempo': 148.937,
#    'type': 'audio_features',
#    'id': '3pcCifdPTc2BbqmWpEhtUd',
#    'uri': 'spotify:track:3pcCifdPTc2BbqmWpEhtUd',
#    'track_href': 'https://api.spotify.com/v1/tracks/3pcCifdPTc2BbqmWpEhtUd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pcCifdPTc2BbqmWpEhtUd',
#    'duration_ms': 220609,
#    'time_signature': 4}],
#  [{'danceability': 0.299,
#    'energy': 0.263,
#    'key': 9,
#    'loudness': -13.207,
#    'mode': 0,
#    'speechiness': 0.0323,
#    'acousticness': 0.968,
#    'instrumentalness': 0.857,
#    'liveness': 0.126,
#    'valence': 0.113,
#    'tempo': 137.848,
#    'type': 'audio_features',
#    'id': '1uRxyAup7OYrlh2SHJb80N',
#    'uri': 'spotify:track:1uRxyAup7OYrlh2SHJb80N',
#    'track_href': 'https://api.spotify.com/v1/tracks/1uRxyAup7OYrlh2SHJb80N',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uRxyAup7OYrlh2SHJb80N',
#    'duration_ms': 384439,
#    'time_signature': 3}],
#  [{'danceability': 0.56,
#    'energy': 0.5,
#    'key': 2,
#    'loudness': -10.829,
#    'mode': 0,
#    'speechiness': 0.0272,
#    'acousticness': 0.668,
#    'instrumentalness': 0.833,
#    'liveness': 0.117,
#    'valence': 0.249,
#    'tempo': 139.174,
#    'type': 'audio_features',
#    'id': '5rIhBK9aaVMck0W2YtOwci',
#    'uri': 'spotify:track:5rIhBK9aaVMck0W2YtOwci',
#    'track_href': 'https://api.spotify.com/v1/tracks/5rIhBK9aaVMck0W2YtOwci',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rIhBK9aaVMck0W2YtOwci',
#    'duration_ms': 281011,
#    'time_signature': 4}],
#  [{'danceability': 0.561,
#    'energy': 0.282,
#    'key': 0,
#    'loudness': -13.241,
#    'mode': 1,
#    'speechiness': 0.0286,
#    'acousticness': 0.868,
#    'instrumentalness': 0.529,
#    'liveness': 0.11,
#    'valence': 0.158,
#    'tempo': 112.011,
#    'type': 'audio_features',
#    'id': '1kBGeOp1CDUHVdbK4ergqo',
#    'uri': 'spotify:track:1kBGeOp1CDUHVdbK4ergqo',
#    'track_href': 'https://api.spotify.com/v1/tracks/1kBGeOp1CDUHVdbK4ergqo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1kBGeOp1CDUHVdbK4ergqo',
#    'duration_ms': 224698,
#    'time_signature': 1}],
#  [{'danceability': 0.426,
#    'energy': 0.661,
#    'key': 0,
#    'loudness': -9.877,
#    'mode': 1,
#    'speechiness': 0.0503,
#    'acousticness': 0.353,
#    'instrumentalness': 0.94,
#    'liveness': 0.619,
#    'valence': 0.178,
#    'tempo': 151.191,
#    'type': 'audio_features',
#    'id': '4CzTgOmc3Sdm4EgKQWzjQl',
#    'uri': 'spotify:track:4CzTgOmc3Sdm4EgKQWzjQl',
#    'track_href': 'https://api.spotify.com/v1/tracks/4CzTgOmc3Sdm4EgKQWzjQl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CzTgOmc3Sdm4EgKQWzjQl',
#    'duration_ms': 367349,
#    'time_signature': 3}],
#  [{'danceability': 0.218,
#    'energy': 0.11,
#    'key': 8,
#    'loudness': -15.721,
#    'mode': 1,
#    'speechiness': 0.0344,
#    'acousticness': 0.955,
#    'instrumentalness': 0.557,
#    'liveness': 0.138,
#    'valence': 0.0616,
#    'tempo': 105.113,
#    'type': 'audio_features',
#    'id': '0eZN5WsQfmNFICHuw59Zfz',
#    'uri': 'spotify:track:0eZN5WsQfmNFICHuw59Zfz',
#    'track_href': 'https://api.spotify.com/v1/tracks/0eZN5WsQfmNFICHuw59Zfz',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eZN5WsQfmNFICHuw59Zfz',
#    'duration_ms': 172936,
#    'time_signature': 4}],
#  [{'danceability': 0.692,
#    'energy': 0.458,
#    'key': 11,
#    'loudness': -9.461,
#    'mode': 0,
#    'speechiness': 0.0403,
#    'acousticness': 0.0635,
#    'instrumentalness': 0.516,
#    'liveness': 0.136,
#    'valence': 0.35,
#    'tempo': 150.695,
#    'type': 'audio_features',
#    'id': '3LhtqibvTtjOUrzKs7Vsz1',
#    'uri': 'spotify:track:3LhtqibvTtjOUrzKs7Vsz1',
#    'track_href': 'https://api.spotify.com/v1/tracks/3LhtqibvTtjOUrzKs7Vsz1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LhtqibvTtjOUrzKs7Vsz1',
#    'duration_ms': 266644,
#    'time_signature': 4}],
#  [{'danceability': 0.282,
#    'energy': 0.372,
#    'key': 5,
#    'loudness': -9.771,
#    'mode': 1,
#    'speechiness': 0.0316,
#    'acousticness': 0.652,
#    'instrumentalness': 0.416,
#    'liveness': 0.0754,
#    'valence': 0.0552,
#    'tempo': 105.215,
#    'type': 'audio_features',
#    'id': '6f6pEjgfTtuRROmJ4a7Gf3',
#    'uri': 'spotify:track:6f6pEjgfTtuRROmJ4a7Gf3',
#    'track_href': 'https://api.spotify.com/v1/tracks/6f6pEjgfTtuRROmJ4a7Gf3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6f6pEjgfTtuRROmJ4a7Gf3',
#    'duration_ms': 345887,
#    'time_signature': 3}],
#  [{'danceability': 0.479,
#    'energy': 0.407,
#    'key': 1,
#    'loudness': -12.428,
#    'mode': 0,
#    'speechiness': 0.0346,
#    'acousticness': 0.912,
#    'instrumentalness': 0.401,
#    'liveness': 0.11,
#    'valence': 0.338,
#    'tempo': 91.91,
#    'type': 'audio_features',
#    'id': '4eruRiSfDY1jdT03hjyi0i',
#    'uri': 'spotify:track:4eruRiSfDY1jdT03hjyi0i',
#    'track_href': 'https://api.spotify.com/v1/tracks/4eruRiSfDY1jdT03hjyi0i',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eruRiSfDY1jdT03hjyi0i',
#    'duration_ms': 306581,
#    'time_signature': 4}],
#  [{'danceability': 0.336,
#    'energy': 0.435,
#    'key': 8,
#    'loudness': -10.944,
#    'mode': 0,
#    'speechiness': 0.0305,
#    'acousticness': 0.73,
#    'instrumentalness': 0.797,
#    'liveness': 0.106,
#    'valence': 0.0507,
#    'tempo': 88.205,
#    'type': 'audio_features',
#    'id': '3cual6JOG286qZJmCxKRAT',
#    'uri': 'spotify:track:3cual6JOG286qZJmCxKRAT',
#    'track_href': 'https://api.spotify.com/v1/tracks/3cual6JOG286qZJmCxKRAT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3cual6JOG286qZJmCxKRAT',
#    'duration_ms': 303689,
#    'time_signature': 4}],
#  [{'danceability': 0.282,
#    'energy': 0.132,
#    'key': 0,
#    'loudness': -15.569,
#    'mode': 1,
#    'speechiness': 0.0375,
#    'acousticness': 0.938,
#    'instrumentalness': 0.104,
#    'liveness': 0.1,
#    'valence': 0.0379,
#    'tempo': 136.186,
#    'type': 'audio_features',
#    'id': '01ZpFhrMMqKPVCwyqXneVp',
#    'uri': 'spotify:track:01ZpFhrMMqKPVCwyqXneVp',
#    'track_href': 'https://api.spotify.com/v1/tracks/01ZpFhrMMqKPVCwyqXneVp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01ZpFhrMMqKPVCwyqXneVp',
#    'duration_ms': 283464,
#    'time_signature': 4}]]

# %%
tracks_objects = []
tracks_audio_features = []

# %%
#get song objects and audio features
for songs in tqdm(song_ids2):
    for song in songs:
        if song != 'Spotify features Not found':
            time.sleep(1)
            objects = GetTrackDescription(song)
            tracks_objects.append(objects)
            features = GetTrackInfo(song)
            tracks_audio_features.append(features)
            with open('features_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_audio_features, f)
            with open('object_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_objects, f)
        else:
            tracks_objects.append({'status':'Not found'})
            tracks_audio_features.append({'status':'Not found'})
            with open('features_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_audio_features, f)
            with open('object_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_objects, f)

# %%
#had to stop at song_ids2[2337] due to time constraints

# %%
tracks_audio_features[0][0]
# Out:
# [{'danceability': 0.79,
#   'energy': 0.599,
#   'key': 7,
#   'loudness': -7.417,
#   'mode': 1,
#   'speechiness': 0.0431,
#   'acousticness': 0.218,
#   'instrumentalness': 0.00257,
#   'liveness': 0.118,
#   'valence': 0.362,
#   'tempo': 109.978,
#   'type': 'audio_features',
#   'id': '2moHnkHTSXBe9KjvPSQJvg',
#   'uri': 'spotify:track:2moHnkHTSXBe9KjvPSQJvg',
#   'track_href': 'https://api.spotify.com/v1/tracks/2moHnkHTSXBe9KjvPSQJvg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2moHnkHTSXBe9KjvPSQJvg',
#   'duration_ms': 266116,
#   'time_signature': 4}]

# %%
tracks_objects[0][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#   'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#   'id': '4HXpQ5KQBVWN25ltjnX7xa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#     'width': 64}],
#   'name': 'Petals For Armor',
#   'release_date': '2020-05-08',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#    'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#    'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#    'name': 'Hayley Williams',
#    'type': 'artist',
#    'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'SA',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 266115,
#  'explicit': True,
#  'external_ids': {'isrc': 'USAT22000079'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2moHnkHTSXBe9KjvPSQJvg'},
#  'href': 'https://api.spotify.com/v1/tracks/2moHnkHTSXBe9KjvPSQJvg',
#  'id': '2moHnkHTSXBe9KjvPSQJvg',
#  'is_local': False,
#  'name': 'Simmer',
#  'popularity': 64,
#  'preview_url': 'https://p.scdn.co/mp3-preview/0257f7fba691830fc450dcd77f42d7f7398d2c40?cid=e60fd635aa7d490b9fa4e73768641362',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:2moHnkHTSXBe9KjvPSQJvg'}

# %% [markdown]
# ## 5. Format collected data into pandas dataframe

# %%
#read in pickled data
tracks_audio_features = pd.read_pickle('features_spotify.pkl')
tracks_objects = pd.read_pickle('object_spotify.pkl')

# %%
#flatten lists
flat_tracks_objects = [item for sublist in tracks_objects for item in sublist]
flat_tracks_audio_features = [item for sublist in tracks_audio_features for item in sublist]

# %%
#create objects dataframe with desired columns
objects_df = pd.DataFrame(columns=[
    'name',
    'duration_ms',
    'popularity',
    'num_markets',
    'album',
    'disc_number',
    'is_explicit',
    'track_number',
    'release_date',
    'artist',
    'song_id'
])

# %%
#create song features dataframe with desired columns
features_df = pd.DataFrame(columns=[
    'danceability',
    'energy',
    'key',
    'loudness',
    'mode',
    'speechiness',
    'acousticness',
    'instrumentalness',
    'liveness',
    'valence',
    'tempo',
    'time_signature',
    'song_id'
])

# %%
#get song objects dictionary data into a dataframe
for song in flat_track_objects:
    if song == {'status': 'Not found'} or song == [None]:
        y = {
            'name': None,
            'duration_ms': None,
            'popularity': None,
            'num_markets': None,
            'album': None,
            'disc_number': None,
            'is_explicit': None,
            'track_number': None,
            'release_date': None,
            'artist': None,
            'song_id': None,
            'album_id': None
        }
        objects_df = objects_df.append(y, ignore_index=True)
    else:
        try:
            y = {
                'name': song['name'],
                'duration_ms': song['duration_ms'],
                'popularity':song['popularity'],
                'num_markets': len(song['available_markets']),
                'album': song['album']['name'],
                'disc_number': song['disc_number'],
                'is_explicit': song['explicit'],
                'track_number': song['track_number'],
                'release_date': song['album']['release_date'],
                'artist': song['artists'][0]['name'],
                'song_id': song['id'],
                'album_id': song['album']['id']
        }
        except:
             y = {
                'name': None,
                'duration_ms': None,
                'popularity': None,
                'num_markets': None,
                'album': None,
                'disc_number': None,
                'is_explicit': None,
                'track_number': None,
                'release_date': None,
                'artist': None,
                'song_id': None,
                'album_id': None
        }
        objects_df = objects_df.append(y, ignore_index=True)

# %%
objects_df.head()
# Out:
#              name duration_ms popularity num_markets             album  \
# 0          Simmer      266115         64          79  Petals For Armor
# 1  Leave It Alone      245076         61          79  Petals For Armor
# 2        Cinnamon      211834         61          79  Petals For Armor
# 3        Creepin'      178398         60          79  Petals For Armor
# 4   Sudden Desire      187969         60          79  Petals For Armor
#
#   disc_number is_explicit track_number release_date           artist  \
# 0           1        True            1   2020-05-08  Hayley Williams
# 1           1       False            2   2020-05-08  Hayley Williams
# 2           1       False            3   2020-05-08  Hayley Williams
# 3           1       False            4   2020-05-08  Hayley Williams
# 4           1       False            5   2020-05-08  Hayley Williams
#
#                   song_id                album_id
# 0  2moHnkHTSXBe9KjvPSQJvg  4HXpQ5KQBVWN25ltjnX7xa
# 1  5ccn0VZg8HQZsZXxGx7UZQ  4HXpQ5KQBVWN25ltjnX7xa
# 2  48pL4zB6KXWPvd7Ln33ENy  4HXpQ5KQBVWN25ltjnX7xa
# 3  5ZD0jxyhmdNZ3DwDRXqV5U  4HXpQ5KQBVWN25ltjnX7xa
# 4  1y2GDXFvtHPbCkHFYg49Gn  4HXpQ5KQBVWN25ltjnX7xa

# %%
objects_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23897 entries, 0 to 23896
# Data columns (total 12 columns):
# name            23525 non-null object
# duration_ms     23525 non-null object
# popularity      23525 non-null object
# num_markets     23525 non-null object
# album           23525 non-null object
# disc_number     23525 non-null object
# is_explicit     23525 non-null object
# track_number    23525 non-null object
# release_date    23525 non-null object
# artist          23525 non-null object
# song_id         23525 non-null object
# album_id        23525 non-null object
# dtypes: object(12)
# memory usage: 2.2+ MB

# %%
#save dataframe
with open('song_objects_df.pkl', 'wb') as f:
    pickle.dump(objects_df, f)

# %%
#get song features dictionary data into a dataframe
for song_object in flat_tracks_audio_features:
    for song in song_object:
        if song == {'status': 'Not found'} or song == [None]:
            y = {
                'danceability': None,
                'energy': None,
                'key': None,
                'loudness': None,
                'mode': None,
                'speechiness': None,
                'acousticness': None,
                'instrumentalness': None,
                'liveness': None,
                'valence': None,
                'tempo': None,
                'time_signature': None,
                'song_id': None
                }
            features_df = features_df.append(y, ignore_index=True)
        else:
            try:
                y = {
                    'danceability': song['danceability'],
                    'energy': song['energy'],
                    'key': song['key'],
                    'loudness': song['loudness'],
                    'mode': song['mode'],
                    'speechiness': song['speechiness'],
                    'acousticness': song['acousticness'],
                    'instrumentalness': song['instrumentalness'],
                    'liveness': song['liveness'],
                    'valence': song['valence'],
                    'tempo': song['tempo'],
                    'time_signature': song['time_signature'],
                    'song_id': song['id']
            }
            except:
                 y = {
                    'danceability': None,
                    'energy': None,
                    'key': None,
                    'loudness': None,
                    'mode': None,
                    'speechiness': None,
                    'acousticness': None,
                    'instrumentalness': None,
                    'liveness': None,
                    'valence': None,
                    'tempo': None,
                    'time_signature': None,
                    'song_id': None
            }
            features_df = features_df.append(y, ignore_index=True)

# %%
features_df.head()
# Out:
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.790   0.599     7    -7.417     1       0.0431         0.218
# 1         0.570   0.339     2   -11.857     0       0.0449         0.569
# 2           NaN     NaN  None       NaN  None          NaN           NaN
# 3         0.877   0.598     6    -6.292     0       0.0296         0.353
# 4         0.564   0.391     7    -7.816     1       0.0785         0.235
#
#    instrumentalness  liveness  valence    tempo time_signature  \
# 0          0.002570     0.118    0.362  109.978              4
# 1          0.451000     0.126    0.442   88.963              4
# 2               NaN       NaN      NaN      NaN           None
# 3          0.001320     0.380    0.671   97.012              4
# 4          0.000054     0.110    0.419  101.449              4
#
#                   song_id
# 0  2moHnkHTSXBe9KjvPSQJvg
# 1  5ccn0VZg8HQZsZXxGx7UZQ
# 2                    None
# 3  5ZD0jxyhmdNZ3DwDRXqV5U
# 4  1y2GDXFvtHPbCkHFYg49Gn

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25757 entries, 0 to 25756
# Data columns (total 13 columns):
# danceability        23520 non-null float64
# energy              23520 non-null float64
# key                 23520 non-null object
# loudness            23520 non-null float64
# mode                23520 non-null object
# speechiness         23520 non-null float64
# acousticness        23520 non-null float64
# instrumentalness    23520 non-null float64
# liveness            23520 non-null float64
# valence             23520 non-null float64
# tempo               23520 non-null float64
# time_signature      23520 non-null object
# song_id             23520 non-null object
# dtypes: float64(9), object(4)
# memory usage: 2.6+ MB

# %%
#save dataframe
with open('song_features_df.pkl', 'wb') as f:
    pickle.dump(features_df, f)
