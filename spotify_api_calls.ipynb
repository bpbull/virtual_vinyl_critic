# %%
import pandas as pd
import time
from tqdm import tqdm
import pickle
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

# %% [markdown]
# # Spotify Data Collection

# %% [markdown]
# ## 1. Establish credentials

# %%
#spotify API credentials

CLIENT_ID = "e60fd635aa7d490b9fa4e73768641362"
CLIENT_SECRET = "f0f4f0288609468a8fbe8681d3676f91"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
sp = spotipy.Spotify(auth=token)
# Out:
# /Users/brendonius/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   del sys.path[0]

# %% [markdown]
# ## 2. Import and format data from Pitchfork

# %%
#import dataframe from pitchfork web scraping
pitchfork_df = pd.read_pickle('pitchfork_df.pickle')

# %%
pitchfork_df.head()
# Out:
#                          Album           Artist Score       Genres  \
# 0             Petals for Armor  Hayley Williams   7.2  Pop/R&BRock
# 1                      Regresa       Buscabulla   7.7   Electronic
# 2          What’s New, Tomboy?    Damien Jurado   7.3         Rock
# 3                  Shadow Talk       Cafe Racer   7.4         Rock
# 4  It Was Good Until It Wasn’t          Kehlani   7.7      Pop/R&B
#
#                                              Summary
# 0  The Paramore singer’s debut solo album is emot...
# 1  The Puerto Rican duo moved back to the island ...
# 2  Channeling stripped-back pop songs into hushed...
# 3  The Chicago band’s third album brings wiry new...
# 4  The cloudy grooves of the Oakland singer’s sec...

# %%
#creat list of lists for album-artist pairs in order to search spotify
alb_art_pairs = [[pitchfork_df.Album[x], pitchfork_df.Artist[x]] for x in range(len(pitchfork_df))]

# %%
len(alb_art_pairs)
# Out:
# 6516

# %%
alb_art_pairs[0:5]
# Out:
# [['Petals for Armor', 'Hayley Williams'],
#  ['Regresa', 'Buscabulla'],
#  ['What’s New, Tomboy?', 'Damien Jurado'],
#  ['Shadow Talk', 'Cafe Racer'],
#  ['It Was Good Until It Wasn’t', 'Kehlani']]

# %% [markdown]
# ## 3. Gather Spotify data about albums

# %%
#function for getting spotify album ID's from album name and artist pair
def GetAlbumID(album, artist):
    results = sp.search(q = "album:" + album + ' artist:' + artist, type = "album")
    return results['albums']['items'][0]['uri']

# %%
#test function
a = GetAlbumID('A Moon Shaped Pool', "Radiohead")
a
# Out:
# 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'

# %%
album_IDs2_combo = []
album_IDs2 = []

# %%
#get spotify albums' ID's
for pair in tqdm(alb_art_pairs[4180:]):
    time.sleep(1)
    try:
        album_IDs2_combo.append([GetAlbumID(pair[0],pair[1]),pair[0],pair[1]])
        album_IDs2.append([GetAlbumID(pair[0],pair[1])])
    except:
        album_IDs2_combo.append(['Spotify features Not found',pair[0],pair[1]])
        album_IDs2.append(['Spotify features Not found'])
# Out:
# HBox(children=(IntProgress(value=0, max=2336), HTML(value='')))

# %%
#function for getting album popularity
def GetAlbumPopularity(album_id):
    album_data = sp.album(album_id)
    return album_data['popularity']

# %%
#test function
b = GetAlbumPopularity(a)
b
# Out:
# 66

# %%
#function for getting the track ID's for all of the songs in an album
def GetTrackIDs(album_id):
    track_id_list = []
    track_ids = sp.album_tracks(album_id)
    for track in track_ids['items']:
        track_id_list.append(track['id'])
    return track_id_list

# %%
#test function
c = GetTrackIDs(a)
c
# Out:
# ['3pcCifdPTc2BbqmWpEhtUd',
#  '1uRxyAup7OYrlh2SHJb80N',
#  '5rIhBK9aaVMck0W2YtOwci',
#  '1kBGeOp1CDUHVdbK4ergqo',
#  '4CzTgOmc3Sdm4EgKQWzjQl',
#  '0eZN5WsQfmNFICHuw59Zfz',
#  '3LhtqibvTtjOUrzKs7Vsz1',
#  '6f6pEjgfTtuRROmJ4a7Gf3',
#  '4eruRiSfDY1jdT03hjyi0i',
#  '3cual6JOG286qZJmCxKRAT',
#  '01ZpFhrMMqKPVCwyqXneVp']

# %%
song_ids_album2 = []
song_ids2 = []
album_pop2_name = []
album_pop2 = []

# %%
#get spotify ID's for all of the tracks in all albums and album popularity
for album in tqdm(album_IDs2[5087:]):
    for alb in album:
        time.sleep(1)
        try:
            song_ids_album2.append([GetTrackIDs(alb),alb])
            song_ids2.append([GetTrackIDs(alb)])
            album_pop2_name.append([GetAlbumPopularity(alb), alb])
            album_pop2.append([GetAlbumPopularity(alb)])
        except:
            song_ids_album2.append(['Spotify features Not found',alb])
            song_ids2.append(['Spotify features Not found'])
            album_pop2_name.append(['Spotify features Not found',alb])
            album_pop2.append(['Spotify features Not found'])
# Out:
#   0%|          | 0/1426 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 1/1426 [00:01<29:31,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 2/1426 [00:02<29:35,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 3/1426 [00:03<29:30,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 4/1426 [00:04<29:18,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 5/1426 [00:06<29:09,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 6/1426 [00:07<29:04,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 7/1426 [00:08<29:01,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 8/1426 [00:09<29:06,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 9/1426 [00:10<28:03,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 10/1426 [00:12<28:19,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 11/1426 [00:13<28:43,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 12/1426 [00:14<27:43,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 13/1426 [00:15<28:07,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 14/1426 [00:17<28:33,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 15/1426 [00:18<28:28,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 16/1426 [00:19<28:31,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 17/1426 [00:20<28:51,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 18/1426 [00:21<28:53,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 19/1426 [00:23<29:06,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 20/1426 [00:24<27:47,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 21/1426 [00:25<28:02,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 22/1426 [00:26<28:29,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 23/1426 [00:27<27:22,  1.17s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 24/1426 [00:28<26:32,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 25/1426 [00:30<27:04,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 26/1426 [00:31<27:33,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 27/1426 [00:32<27:51,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 28/1426 [00:33<28:32,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 29/1426 [00:35<28:32,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 30/1426 [00:36<28:22,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 31/1426 [00:37<28:25,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 32/1426 [00:38<28:31,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 33/1426 [00:39<28:28,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 34/1426 [00:41<28:18,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 35/1426 [00:42<28:21,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 36/1426 [00:43<27:13,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 37/1426 [00:44<26:21,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 38/1426 [00:45<27:01,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 39/1426 [00:46<27:23,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 40/1426 [00:48<27:44,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 41/1426 [00:49<27:52,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 42/1426 [00:50<27:52,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 43/1426 [00:51<28:04,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 44/1426 [00:53<28:12,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 45/1426 [00:54<28:12,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 46/1426 [00:55<28:23,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 47/1426 [00:56<28:32,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 48/1426 [00:58<28:27,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 49/1426 [00:59<28:16,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▎         | 50/1426 [01:00<28:06,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▎         | 51/1426 [01:01<28:03,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▎         | 52/1426 [01:02<27:53,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▎         | 53/1426 [01:04<28:03,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 54/1426 [01:05<28:16,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 55/1426 [01:06<28:22,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 56/1426 [01:07<28:36,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 57/1426 [01:09<28:17,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 58/1426 [01:10<28:29,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 59/1426 [01:12<30:34,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 60/1426 [01:13<29:52,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 61/1426 [01:14<29:20,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 62/1426 [01:15<28:57,  1.27s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 63/1426 [01:16<27:26,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 64/1426 [01:18<27:37,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 65/1426 [01:19<26:34,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 66/1426 [01:20<27:06,  1.20s/it]
#   5%|▍         | 67/1426 [01:22<32:21,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 68/1426 [01:23<31:55,  1.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 69/1426 [01:24<30:38,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 70/1426 [01:26<31:03,  1.37s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 71/1426 [01:27<28:51,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 72/1426 [01:28<28:31,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 73/1426 [01:29<29:08,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 74/1426 [01:31<29:01,  1.29s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 75/1426 [01:32<27:25,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 76/1426 [01:33<27:42,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 77/1426 [01:34<27:58,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 78/1426 [01:36<27:45,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 79/1426 [01:37<26:31,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 80/1426 [01:38<25:39,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 81/1426 [01:39<26:09,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 82/1426 [01:40<26:37,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 83/1426 [01:41<26:59,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 84/1426 [01:43<26:59,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 85/1426 [01:44<26:59,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 86/1426 [01:45<27:02,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 87/1426 [01:46<27:07,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 88/1426 [01:47<27:12,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 89/1426 [01:49<27:08,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▋         | 90/1426 [01:50<26:28,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▋         | 91/1426 [01:51<26:45,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▋         | 92/1426 [01:52<26:48,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 93/1426 [01:54<27:12,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 94/1426 [01:55<27:06,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 95/1426 [01:56<29:24,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 96/1426 [01:58<28:47,  1.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 97/1426 [01:59<28:26,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 98/1426 [02:00<28:09,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 99/1426 [02:01<28:00,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 100/1426 [02:03<27:35,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 101/1426 [02:04<27:50,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 102/1426 [02:05<27:36,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 103/1426 [02:06<26:19,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 104/1426 [02:07<25:27,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 105/1426 [02:08<26:09,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 106/1426 [02:10<26:42,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 107/1426 [02:11<26:50,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 108/1426 [02:12<26:52,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 109/1426 [02:13<26:50,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 110/1426 [02:15<26:55,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 111/1426 [02:16<27:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 112/1426 [02:17<27:21,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 113/1426 [02:18<27:06,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 114/1426 [02:20<27:21,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 115/1426 [02:21<28:40,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 116/1426 [02:22<28:26,  1.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 117/1426 [02:24<29:17,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 118/1426 [02:25<28:32,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 119/1426 [02:26<27:52,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 120/1426 [02:27<27:27,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 121/1426 [02:29<27:12,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▊         | 122/1426 [02:30<27:02,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▊         | 123/1426 [02:31<26:52,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▊         | 124/1426 [02:32<27:03,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 125/1426 [02:34<27:20,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 126/1426 [02:35<27:14,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 127/1426 [02:36<27:20,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 128/1426 [02:37<27:16,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 129/1426 [02:39<27:12,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 130/1426 [02:40<27:48,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 131/1426 [02:41<27:20,  1.27s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 132/1426 [02:42<25:59,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 133/1426 [02:44<26:42,  1.24s/it]
#   9%|▉         | 134/1426 [02:45<26:46,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 135/1426 [02:46<26:49,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 136/1426 [02:47<25:36,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 137/1426 [02:48<24:44,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 138/1426 [02:50<25:36,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 139/1426 [02:51<25:53,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 140/1426 [02:52<25:58,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 141/1426 [02:54<28:42,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 142/1426 [02:55<27:53,  1.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 143/1426 [02:56<27:43,  1.30s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 144/1426 [02:57<26:11,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 145/1426 [02:59<26:10,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 146/1426 [03:00<26:45,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 147/1426 [03:01<25:27,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 148/1426 [03:02<24:37,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 149/1426 [03:03<25:18,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 150/1426 [03:04<25:46,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 151/1426 [03:06<25:53,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 152/1426 [03:07<26:06,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 153/1426 [03:08<26:14,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 154/1426 [03:09<25:02,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 155/1426 [03:11<25:28,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 156/1426 [03:12<26:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 157/1426 [03:13<25:51,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 158/1426 [03:14<26:25,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 159/1426 [03:16<26:21,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 160/1426 [03:17<26:43,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█▏        | 161/1426 [03:18<26:41,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█▏        | 162/1426 [03:19<26:25,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█▏        | 163/1426 [03:21<26:10,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 164/1426 [03:22<25:00,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 165/1426 [03:23<25:14,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 166/1426 [03:24<25:30,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 167/1426 [03:25<25:44,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 168/1426 [03:27<25:52,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 169/1426 [03:28<25:50,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 170/1426 [03:29<25:52,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 171/1426 [03:30<25:56,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 172/1426 [03:32<25:50,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 173/1426 [03:33<25:45,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 174/1426 [03:34<25:47,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 175/1426 [03:35<24:47,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 176/1426 [03:36<24:54,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 177/1426 [03:38<24:59,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 178/1426 [03:39<25:22,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 179/1426 [03:40<24:25,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 180/1426 [03:41<24:36,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 181/1426 [03:42<25:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 182/1426 [03:44<25:28,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 183/1426 [03:45<25:45,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 184/1426 [03:46<26:09,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 185/1426 [03:47<24:49,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 186/1426 [03:49<25:02,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 187/1426 [03:50<25:11,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 188/1426 [03:51<25:33,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 189/1426 [03:52<25:39,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 190/1426 [03:54<25:42,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 191/1426 [03:55<25:59,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 192/1426 [03:56<24:42,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▎        | 193/1426 [03:57<24:51,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▎        | 194/1426 [03:58<23:54,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▎        | 195/1426 [03:59<24:17,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▎        | 196/1426 [04:01<24:29,  1.19s/it]
#  14%|█▍        | 197/1426 [04:02<24:36,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 198/1426 [04:03<24:39,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 199/1426 [04:04<23:44,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 200/1426 [04:05<24:08,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 201/1426 [04:07<24:25,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 202/1426 [04:08<24:32,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 203/1426 [04:09<24:33,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 204/1426 [04:10<24:39,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 205/1426 [04:11<23:45,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 206/1426 [04:13<24:21,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 207/1426 [04:14<23:35,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 208/1426 [04:15<24:09,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 209/1426 [04:16<24:19,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 210/1426 [04:18<27:58,  1.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 211/1426 [04:20<31:33,  1.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 212/1426 [04:21<29:27,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 213/1426 [04:22<28:06,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 214/1426 [04:24<27:26,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 215/1426 [04:25<26:31,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 216/1426 [04:26<26:07,  1.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 217/1426 [04:27<25:40,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 218/1426 [04:29<25:15,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 219/1426 [04:30<25:25,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 220/1426 [04:31<25:18,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 221/1426 [04:32<24:03,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 222/1426 [04:33<24:39,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 223/1426 [04:34<23:34,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 224/1426 [04:36<23:53,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 225/1426 [04:37<24:01,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 226/1426 [04:38<23:07,  1.16s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 227/1426 [04:39<22:30,  1.13s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 228/1426 [04:40<22:03,  1.10s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 229/1426 [04:41<21:44,  1.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 230/1426 [04:42<22:37,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 231/1426 [04:44<23:01,  1.16s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▋        | 232/1426 [04:45<22:22,  1.12s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▋        | 233/1426 [04:46<21:55,  1.10s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▋        | 234/1426 [04:47<21:38,  1.09s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▋        | 235/1426 [04:48<21:29,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 236/1426 [04:49<22:26,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 237/1426 [04:51<24:39,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 238/1426 [04:52<24:40,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 239/1426 [04:53<25:05,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 240/1426 [04:54<24:48,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 241/1426 [04:55<23:38,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 242/1426 [04:57<24:03,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 243/1426 [04:58<24:12,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 244/1426 [04:59<24:42,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 245/1426 [05:01<24:40,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 246/1426 [05:02<24:31,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 247/1426 [05:03<23:23,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 248/1426 [05:04<23:33,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 249/1426 [05:05<23:50,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 250/1426 [05:07<23:56,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 251/1426 [05:08<23:05,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 252/1426 [05:09<23:52,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 253/1426 [05:10<23:55,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 254/1426 [05:11<23:57,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 255/1426 [05:13<24:14,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#  18%|█▊        | 256/1426 [05:14<23:16,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 257/1426 [05:15<23:35,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 258/1426 [05:16<23:46,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 259/1426 [05:17<23:47,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 260/1426 [05:19<23:48,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 261/1426 [05:20<22:47,  1.17s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 262/1426 [05:21<22:04,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 263/1426 [05:22<22:59,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 264/1426 [05:24<24:50,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 265/1426 [05:25<24:21,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 266/1426 [05:26<23:12,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 267/1426 [05:27<24:07,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 268/1426 [05:28<23:54,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 269/1426 [05:30<22:52,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 270/1426 [05:31<22:04,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 271/1426 [05:32<22:49,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 272/1426 [05:33<22:04,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 273/1426 [05:34<22:30,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 274/1426 [05:35<23:12,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 275/1426 [05:37<22:19,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 276/1426 [05:38<22:43,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 277/1426 [05:39<21:57,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 278/1426 [05:40<22:21,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 279/1426 [05:41<22:36,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 280/1426 [05:42<22:51,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 281/1426 [05:44<23:09,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 282/1426 [05:45<22:13,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 283/1426 [05:46<22:46,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 284/1426 [05:47<22:52,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 285/1426 [05:48<22:58,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 286/1426 [05:50<23:05,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 287/1426 [05:51<23:35,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 288/1426 [05:52<22:31,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 289/1426 [05:53<22:50,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 290/1426 [05:55<22:57,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 291/1426 [05:56<22:57,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 292/1426 [05:57<23:02,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 293/1426 [05:58<23:23,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 294/1426 [05:59<22:29,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 295/1426 [06:01<22:39,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 296/1426 [06:02<22:51,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 297/1426 [06:03<22:51,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 298/1426 [06:04<21:55,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 299/1426 [06:05<22:32,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 300/1426 [06:07<22:36,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 301/1426 [06:08<22:42,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 302/1426 [06:09<21:48,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 303/1426 [06:10<22:17,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██▏       | 304/1426 [06:11<21:35,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██▏       | 305/1426 [06:12<22:20,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██▏       | 306/1426 [06:14<22:35,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 307/1426 [06:15<22:38,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 308/1426 [06:16<21:43,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 309/1426 [06:17<22:09,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 310/1426 [06:18<22:16,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 311/1426 [06:20<22:27,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 312/1426 [06:21<22:49,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 313/1426 [06:22<21:48,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#  22%|██▏       | 314/1426 [06:23<21:09,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 315/1426 [06:24<21:38,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 316/1426 [06:26<21:53,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 317/1426 [06:27<22:00,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 318/1426 [06:28<22:06,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 319/1426 [06:29<22:17,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 320/1426 [06:30<22:40,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 321/1426 [06:32<21:40,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 322/1426 [06:33<22:02,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 323/1426 [06:34<22:18,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 324/1426 [06:35<22:22,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 325/1426 [06:37<22:37,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 326/1426 [06:38<24:47,  1.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 327/1426 [06:39<24:17,  1.33s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 328/1426 [06:41<22:58,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 329/1426 [06:42<23:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 330/1426 [06:43<22:58,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 331/1426 [06:44<21:49,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 332/1426 [06:45<22:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 333/1426 [06:47<22:08,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 334/1426 [06:48<22:36,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 335/1426 [06:49<22:29,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▎       | 336/1426 [06:50<22:34,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▎       | 337/1426 [06:52<23:25,  1.29s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▎       | 338/1426 [06:53<22:06,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 339/1426 [06:54<22:06,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 340/1426 [06:55<22:07,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 341/1426 [06:57<23:24,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 342/1426 [06:58<22:58,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 343/1426 [07:00<25:32,  1.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 344/1426 [07:01<24:30,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 345/1426 [07:02<23:43,  1.32s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 346/1426 [07:03<22:31,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 347/1426 [07:04<22:29,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 348/1426 [07:06<22:21,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 349/1426 [07:07<21:19,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 350/1426 [07:08<20:34,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 351/1426 [07:09<21:15,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 352/1426 [07:10<21:33,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 353/1426 [07:12<22:06,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 354/1426 [07:13<22:05,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 355/1426 [07:14<21:58,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 356/1426 [07:15<21:00,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 357/1426 [07:17<23:08,  1.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 358/1426 [07:18<22:41,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 359/1426 [07:19<22:28,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 360/1426 [07:20<22:28,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 361/1426 [07:22<24:40,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 362/1426 [07:23<23:51,  1.35s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 363/1426 [07:24<22:18,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 364/1426 [07:26<24:07,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 365/1426 [07:27<23:32,  1.33s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 366/1426 [07:28<22:04,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 367/1426 [07:29<21:02,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 368/1426 [07:30<20:19,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 369/1426 [07:32<20:47,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 370/1426 [07:33<20:59,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 371/1426 [07:34<20:20,  1.16s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#  26%|██▌       | 372/1426 [07:35<19:50,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 373/1426 [07:36<20:29,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 374/1426 [07:38<20:44,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 375/1426 [07:39<20:56,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 376/1426 [07:40<21:43,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 377/1426 [07:41<21:05,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 378/1426 [07:42<20:17,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 379/1426 [07:44<20:43,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 380/1426 [07:45<20:54,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 381/1426 [07:46<21:06,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 382/1426 [07:47<21:16,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 383/1426 [07:48<20:23,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 384/1426 [07:50<20:39,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 385/1426 [07:51<19:54,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 386/1426 [07:52<20:22,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 387/1426 [07:53<20:39,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 388/1426 [07:54<20:46,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 389/1426 [07:56<20:50,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 390/1426 [07:57<20:57,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 391/1426 [07:58<20:59,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 392/1426 [07:59<21:06,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 393/1426 [08:00<20:12,  1.17s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 394/1426 [08:01<19:35,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 395/1426 [08:03<20:20,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 396/1426 [08:04<20:33,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 397/1426 [08:05<20:54,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 398/1426 [08:07<22:22,  1.31s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 399/1426 [08:08<21:15,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 400/1426 [08:09<21:23,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 401/1426 [08:11<24:27,  1.43s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 402/1426 [08:12<22:31,  1.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 403/1426 [08:14<24:21,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 404/1426 [08:15<24:06,  1.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 405/1426 [08:16<23:07,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 406/1426 [08:17<22:23,  1.32s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▊       | 407/1426 [08:18<21:02,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▊       | 408/1426 [08:20<21:12,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▊       | 409/1426 [08:21<21:04,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 410/1426 [08:22<20:06,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 411/1426 [08:23<20:13,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 412/1426 [08:24<20:18,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 413/1426 [08:26<20:24,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 414/1426 [08:27<20:26,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 415/1426 [08:28<20:46,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 416/1426 [08:29<19:51,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 417/1426 [08:30<20:05,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 418/1426 [08:32<20:07,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 419/1426 [08:33<19:24,  1.16s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 420/1426 [08:34<18:52,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 421/1426 [08:35<19:20,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 422/1426 [08:36<19:54,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 423/1426 [08:38<19:59,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 424/1426 [08:39<20:12,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 425/1426 [08:40<20:13,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 426/1426 [08:41<20:24,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 427/1426 [08:42<19:33,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 428/1426 [08:44<19:54,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 429/1426 [08:45<19:11,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 430/1426 [08:46<19:37,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 431/1426 [08:47<19:44,  1.19s/it]
#  30%|███       | 432/1426 [08:48<19:48,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 433/1426 [08:49<19:52,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 434/1426 [08:51<19:55,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 435/1426 [08:52<19:09,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 436/1426 [08:53<19:32,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 437/1426 [08:54<19:48,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 438/1426 [08:55<19:02,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 439/1426 [08:56<19:14,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 440/1426 [08:58<19:42,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 441/1426 [09:00<23:24,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 442/1426 [09:01<22:24,  1.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 443/1426 [09:02<21:43,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 444/1426 [09:03<21:07,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 445/1426 [09:05<20:50,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 446/1426 [09:06<20:39,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 447/1426 [09:07<20:29,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 448/1426 [09:08<20:23,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 449/1426 [09:10<20:13,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 450/1426 [09:11<20:04,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 451/1426 [09:12<19:10,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 452/1426 [09:13<19:47,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 453/1426 [09:14<19:47,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 454/1426 [09:15<18:58,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 455/1426 [09:17<19:46,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 456/1426 [09:18<19:05,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 457/1426 [09:20<22:35,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 458/1426 [09:21<22:28,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 459/1426 [09:22<21:48,  1.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 460/1426 [09:24<21:23,  1.33s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 461/1426 [09:25<20:04,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 462/1426 [09:26<19:51,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 463/1426 [09:27<20:11,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 464/1426 [09:28<20:11,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 465/1426 [09:30<20:00,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 466/1426 [09:31<19:54,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 467/1426 [09:32<19:44,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 468/1426 [09:33<19:50,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 469/1426 [09:35<19:39,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 470/1426 [09:36<19:43,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 471/1426 [09:37<19:40,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 472/1426 [09:38<19:31,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 473/1426 [09:40<19:27,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 474/1426 [09:41<19:36,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 475/1426 [09:42<19:31,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 476/1426 [09:43<19:23,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 477/1426 [09:44<19:28,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 478/1426 [09:46<19:26,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 479/1426 [09:47<19:32,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 480/1426 [09:48<19:25,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 481/1426 [09:49<19:26,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 482/1426 [09:51<19:20,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 483/1426 [09:52<19:21,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 484/1426 [09:53<18:29,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 485/1426 [09:54<18:47,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 486/1426 [09:56<19:45,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 487/1426 [09:57<19:34,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 488/1426 [09:58<19:36,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 489/1426 [09:59<18:40,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 490/1426 [10:00<18:00,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 491/1426 [10:01<18:22,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 492/1426 [10:03<18:36,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 493/1426 [10:04<18:47,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 494/1426 [10:05<18:02,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 495/1426 [10:06<18:20,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#  35%|███▍      | 496/1426 [10:07<17:52,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 497/1426 [10:09<18:26,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 498/1426 [10:10<18:39,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 499/1426 [10:11<18:51,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 500/1426 [10:12<18:56,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 501/1426 [10:14<19:14,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 502/1426 [10:15<19:24,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 503/1426 [10:16<19:15,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 504/1426 [10:17<19:30,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 505/1426 [10:19<19:13,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 506/1426 [10:20<19:37,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 507/1426 [10:21<19:46,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 508/1426 [10:22<19:21,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 509/1426 [10:24<19:27,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 510/1426 [10:25<19:17,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 511/1426 [10:26<19:02,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 512/1426 [10:28<19:36,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 513/1426 [10:29<19:31,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 514/1426 [10:30<19:16,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 515/1426 [10:31<19:10,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 516/1426 [10:33<18:55,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 517/1426 [10:34<18:50,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 518/1426 [10:35<18:42,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 519/1426 [10:36<18:41,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 520/1426 [10:37<18:34,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 521/1426 [10:39<18:50,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 522/1426 [10:40<18:45,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 523/1426 [10:41<18:51,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 524/1426 [10:43<18:48,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 525/1426 [10:44<18:08,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 526/1426 [10:45<18:19,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 527/1426 [10:46<18:20,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 528/1426 [10:47<18:18,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 529/1426 [10:49<18:16,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 530/1426 [10:50<18:34,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 531/1426 [10:51<18:24,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 532/1426 [10:52<18:18,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 533/1426 [10:54<18:15,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 534/1426 [10:55<18:12,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 535/1426 [10:56<18:31,  1.25s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 536/1426 [10:57<17:45,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 537/1426 [10:58<17:05,  1.15s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 538/1426 [10:59<16:44,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 539/1426 [11:01<17:24,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 540/1426 [11:02<19:47,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 541/1426 [11:04<21:08,  1.43s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1258/1426 [25:33<03:25,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1259/1426 [25:35<03:25,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1260/1426 [25:36<03:24,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1261/1426 [25:37<03:23,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1262/1426 [25:38<03:23,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 1263/1426 [25:40<03:21,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 1264/1426 [25:41<03:20,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 1265/1426 [25:42<03:10,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1266/1426 [25:43<03:03,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1267/1426 [25:44<03:08,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1268/1426 [25:45<03:12,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1269/1426 [25:47<03:36,  1.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1270/1426 [25:48<03:28,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1271/1426 [25:50<03:25,  1.33s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1272/1426 [25:51<03:12,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1273/1426 [25:52<03:10,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1274/1426 [25:53<03:09,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1275/1426 [25:55<03:07,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 1276/1426 [25:56<03:05,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1277/1426 [25:57<02:58,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1278/1426 [25:58<02:59,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1279/1426 [25:59<03:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1280/1426 [26:01<03:00,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1281/1426 [26:02<02:51,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1282/1426 [26:03<02:54,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 1283/1426 [26:04<02:53,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1284/1426 [26:05<02:45,  1.17s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1285/1426 [26:06<02:39,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1286/1426 [26:08<02:42,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1287/1426 [26:09<02:43,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1288/1426 [26:10<02:44,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1289/1426 [26:11<02:45,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 1290/1426 [26:12<02:45,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1291/1426 [26:14<02:37,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1292/1426 [26:15<02:41,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1293/1426 [26:16<02:41,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1294/1426 [26:17<02:40,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1295/1426 [26:18<02:32,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1296/1426 [26:20<02:37,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1297/1426 [26:21<02:36,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1298/1426 [26:22<02:36,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1299/1426 [26:23<02:35,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1300/1426 [26:25<02:34,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 1301/1426 [26:26<02:33,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████▏| 1302/1426 [26:27<02:32,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████▏| 1303/1426 [26:28<02:31,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████▏| 1304/1426 [26:30<02:31,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1305/1426 [26:31<02:56,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1306/1426 [26:33<02:49,  1.42s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1307/1426 [26:34<02:35,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1308/1426 [26:35<02:31,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1309/1426 [26:36<02:28,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1310/1426 [26:38<02:25,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1311/1426 [26:39<02:23,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1312/1426 [26:40<02:21,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1313/1426 [26:41<02:14,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1314/1426 [26:42<02:08,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1315/1426 [26:43<02:10,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1316/1426 [26:45<02:12,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1317/1426 [26:46<02:12,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 1318/1426 [26:47<02:11,  1.22s/it]
#  92%|█████████▏| 1319/1426 [26:48<02:10,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1320/1426 [26:50<02:11,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1321/1426 [26:51<02:10,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1322/1426 [26:52<02:16,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1323/1426 [26:54<02:14,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1324/1426 [26:55<02:11,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1325/1426 [26:56<02:14,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1326/1426 [26:58<02:11,  1.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1327/1426 [26:59<02:07,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1328/1426 [27:00<02:03,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1329/1426 [27:01<02:01,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1330/1426 [27:02<01:59,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1331/1426 [27:04<01:57,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1332/1426 [27:05<01:55,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 1333/1426 [27:06<01:49,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▎| 1334/1426 [27:07<01:46,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▎| 1335/1426 [27:08<01:48,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▎| 1336/1426 [27:10<01:48,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1337/1426 [27:11<01:56,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1338/1426 [27:13<02:07,  1.45s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1339/1426 [27:14<01:55,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1340/1426 [27:15<01:52,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1341/1426 [27:16<01:48,  1.27s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1342/1426 [27:17<01:42,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1343/1426 [27:19<01:41,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1344/1426 [27:20<01:40,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1345/1426 [27:21<01:40,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1346/1426 [27:22<01:38,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 1347/1426 [27:24<01:33,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1348/1426 [27:25<01:33,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1349/1426 [27:26<01:32,  1.21s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1350/1426 [27:27<01:28,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1351/1426 [27:28<01:28,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1352/1426 [27:29<01:24,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1353/1426 [27:31<01:26,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 1354/1426 [27:32<01:25,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1355/1426 [27:33<01:21,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1356/1426 [27:34<01:24,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1357/1426 [27:35<01:24,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1358/1426 [27:37<01:20,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1359/1426 [27:38<01:20,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1360/1426 [27:39<01:19,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 1361/1426 [27:40<01:15,  1.16s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1362/1426 [27:41<01:12,  1.13s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1363/1426 [27:42<01:10,  1.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1364/1426 [27:43<01:12,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1365/1426 [27:45<01:12,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1366/1426 [27:46<01:11,  1.20s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1367/1426 [27:47<01:08,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1368/1426 [27:48<01:08,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1369/1426 [27:49<01:05,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1370/1426 [27:51<01:05,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1371/1426 [27:52<01:05,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 1372/1426 [27:53<01:05,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▋| 1373/1426 [27:54<01:05,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▋| 1374/1426 [27:56<01:03,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▋| 1375/1426 [27:57<01:00,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▋| 1376/1426 [27:58<01:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1377/1426 [27:59<00:59,  1.21s/it]
#  97%|█████████▋| 1378/1426 [28:00<00:58,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1379/1426 [28:02<00:57,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1380/1426 [28:03<00:56,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1381/1426 [28:04<00:55,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1382/1426 [28:05<00:51,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1383/1426 [28:06<00:52,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1384/1426 [28:08<00:52,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1385/1426 [28:09<00:50,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1386/1426 [28:10<00:49,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1387/1426 [28:11<00:48,  1.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1388/1426 [28:13<00:48,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1389/1426 [28:14<00:50,  1.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 1390/1426 [28:16<00:48,  1.34s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1391/1426 [28:17<00:44,  1.26s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1392/1426 [28:18<00:40,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1393/1426 [28:19<00:40,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1394/1426 [28:20<00:37,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1395/1426 [28:21<00:36,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1396/1426 [28:22<00:34,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1397/1426 [28:24<00:33,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1398/1426 [28:25<00:33,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1399/1426 [28:26<00:31,  1.16s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1400/1426 [28:27<00:29,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1401/1426 [28:28<00:28,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1402/1426 [28:29<00:28,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1403/1426 [28:31<00:28,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 1404/1426 [28:32<00:27,  1.24s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▊| 1405/1426 [28:33<00:24,  1.19s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▊| 1406/1426 [28:34<00:23,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▊| 1407/1426 [28:35<00:22,  1.17s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▊| 1408/1426 [28:36<00:20,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1409/1426 [28:38<00:20,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1410/1426 [28:39<00:18,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1411/1426 [28:40<00:17,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1412/1426 [28:41<00:16,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1413/1426 [28:43<00:15,  1.23s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1414/1426 [28:44<00:14,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1415/1426 [28:45<00:13,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1416/1426 [28:46<00:12,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1417/1426 [28:47<00:10,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 1418/1426 [28:49<00:09,  1.22s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1419/1426 [28:50<00:08,  1.18s/it]HTTP Error for GET to https://api.spotify.com/v1/albums/Spotify features Not found/tracks/ returned 400 due to invalid id
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1420/1426 [28:51<00:06,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1421/1426 [28:52<00:06,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1422/1426 [28:53<00:04,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1423/1426 [28:55<00:03,  1.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1424/1426 [28:56<00:02,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|█████████▉| 1425/1426 [28:57<00:01,  1.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 1426/1426 [28:59<00:00,  1.22s/it]

# %%
#save the song ids
with open('song_ids.pkl', 'wb') as f:
    pickle.dump(song_ids2, f)

# %% [markdown]
# ## 4. Get Spotify data about songs

# %%
#function for getting information for a list of songs from song IDs
def GetTrackDescription(track_ids):
    track_descriptions = []
    for track_id in track_ids:
        description = sp.track(track_id)
        track_descriptions.append(description)
    return track_descriptions

# %%
#test function
d = GetTrackDescription(c)
d
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 220609,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600071'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3pcCifdPTc2BbqmWpEhtUd'},
#   'href': 'https://api.spotify.com/v1/tracks/3pcCifdPTc2BbqmWpEhtUd',
#   'id': '3pcCifdPTc2BbqmWpEhtUd',
#   'is_local': False,
#   'name': 'Burn the Witch',
#   'popularity': 58,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c5b0b198ee3f045960106e9957550e4610555d7d?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3pcCifdPTc2BbqmWpEhtUd'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 384438,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600072'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1uRxyAup7OYrlh2SHJb80N'},
#   'href': 'https://api.spotify.com/v1/tracks/1uRxyAup7OYrlh2SHJb80N',
#   'id': '1uRxyAup7OYrlh2SHJb80N',
#   'is_local': False,
#   'name': 'Daydreaming',
#   'popularity': 61,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fbf970f6ee1e7d849de08017d3688406107c751a?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1uRxyAup7OYrlh2SHJb80N'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 281011,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600073'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5rIhBK9aaVMck0W2YtOwci'},
#   'href': 'https://api.spotify.com/v1/tracks/5rIhBK9aaVMck0W2YtOwci',
#   'id': '5rIhBK9aaVMck0W2YtOwci',
#   'is_local': False,
#   'name': 'Decks Dark',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3500e1883855236feda78e798f04b4bffad11d43?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:5rIhBK9aaVMck0W2YtOwci'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 224698,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600074'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1kBGeOp1CDUHVdbK4ergqo'},
#   'href': 'https://api.spotify.com/v1/tracks/1kBGeOp1CDUHVdbK4ergqo',
#   'id': '1kBGeOp1CDUHVdbK4ergqo',
#   'is_local': False,
#   'name': 'Desert Island Disk',
#   'popularity': 52,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0a484b7a356f34f1561f126827edd15f02d4d178?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:1kBGeOp1CDUHVdbK4ergqo'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 367348,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600075'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4CzTgOmc3Sdm4EgKQWzjQl'},
#   'href': 'https://api.spotify.com/v1/tracks/4CzTgOmc3Sdm4EgKQWzjQl',
#   'id': '4CzTgOmc3Sdm4EgKQWzjQl',
#   'is_local': False,
#   'name': 'Ful Stop',
#   'popularity': 53,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7b544b63c8c8aa645a3ca9dcbaf4d5ae262fcb61?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:4CzTgOmc3Sdm4EgKQWzjQl'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 172935,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600076'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0eZN5WsQfmNFICHuw59Zfz'},
#   'href': 'https://api.spotify.com/v1/tracks/0eZN5WsQfmNFICHuw59Zfz',
#   'id': '0eZN5WsQfmNFICHuw59Zfz',
#   'is_local': False,
#   'name': 'Glass Eyes',
#   'popularity': 52,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4619aaddaa93174494952f25319cbc85b15b3a04?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:0eZN5WsQfmNFICHuw59Zfz'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 266643,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600077'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3LhtqibvTtjOUrzKs7Vsz1'},
#   'href': 'https://api.spotify.com/v1/tracks/3LhtqibvTtjOUrzKs7Vsz1',
#   'id': '3LhtqibvTtjOUrzKs7Vsz1',
#   'is_local': False,
#   'name': 'Identikit',
#   'popularity': 53,
#   'preview_url': 'https://p.scdn.co/mp3-preview/00db1006a1278a6ae48e4c5688fc51f054caa2f3?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:3LhtqibvTtjOUrzKs7Vsz1'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 345886,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600078'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6f6pEjgfTtuRROmJ4a7Gf3'},
#   'href': 'https://api.spotify.com/v1/tracks/6f6pEjgfTtuRROmJ4a7Gf3',
#   'id': '6f6pEjgfTtuRROmJ4a7Gf3',
#   'is_local': False,
#   'name': 'The Numbers',
#   'popularity': 52,
#   'preview_url': 'https://p.scdn.co/mp3-preview/27702a4de95e61186bbcbe17877eaa75bfc0ba1b?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:6f6pEjgfTtuRROmJ4a7Gf3'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 306581,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600079'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4eruRiSfDY1jdT03hjyi0i'},
#   'href': 'https://api.spotify.com/v1/tracks/4eruRiSfDY1jdT03hjyi0i',
#   'id': '4eruRiSfDY1jdT03hjyi0i',
#   'is_local': False,
#   'name': 'Present Tense',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/587a67dfe955b5582d12e252ec648b98b097001e?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:4eruRiSfDY1jdT03hjyi0i'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 303688,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600080'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3cual6JOG286qZJmCxKRAT'},
#   'href': 'https://api.spotify.com/v1/tracks/3cual6JOG286qZJmCxKRAT',
#   'id': '3cual6JOG286qZJmCxKRAT',
#   'is_local': False,
#   'name': 'Tinker Tailor Soldier Sailor Rich Man Poor Man Beggar Man Thief',
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/28cb214a84754e03d94c5821ad101b901e625b55?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:3cual6JOG286qZJmCxKRAT'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#    'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#    'id': '6vuykQgDLUCiZ7YggIpLM9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#      'width': 64}],
#    'name': 'A Moon Shaped Pool',
#    'release_date': '2016-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#     'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#     'id': '4Z8W4fKeB5YxbusRsdQVPb',
#     'name': 'Radiohead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 283463,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBKS1600081'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/01ZpFhrMMqKPVCwyqXneVp'},
#   'href': 'https://api.spotify.com/v1/tracks/01ZpFhrMMqKPVCwyqXneVp',
#   'id': '01ZpFhrMMqKPVCwyqXneVp',
#   'is_local': False,
#   'name': 'True Love Waits',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4074ab8ea2a8bb98e29a6a9a7b115c7ca15c0272?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:01ZpFhrMMqKPVCwyqXneVp'}]

# %%
#function for getting audio features for a list of tracks
def GetTrackInfo(track_ids):
    tracks_info = []
    for track_id in track_ids:
        info = sp.audio_features(track_id)
        tracks_info.append(info)
    return tracks_info

# %%
#test function
e = GetTrackInfo(c)
e
# Out:
# [[{'danceability': 0.541,
#    'energy': 0.847,
#    'key': 11,
#    'loudness': -6.52,
#    'mode': 1,
#    'speechiness': 0.0297,
#    'acousticness': 0.303,
#    'instrumentalness': 0.271,
#    'liveness': 0.109,
#    'valence': 0.62,
#    'tempo': 148.937,
#    'type': 'audio_features',
#    'id': '3pcCifdPTc2BbqmWpEhtUd',
#    'uri': 'spotify:track:3pcCifdPTc2BbqmWpEhtUd',
#    'track_href': 'https://api.spotify.com/v1/tracks/3pcCifdPTc2BbqmWpEhtUd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pcCifdPTc2BbqmWpEhtUd',
#    'duration_ms': 220609,
#    'time_signature': 4}],
#  [{'danceability': 0.299,
#    'energy': 0.263,
#    'key': 9,
#    'loudness': -13.207,
#    'mode': 0,
#    'speechiness': 0.0323,
#    'acousticness': 0.968,
#    'instrumentalness': 0.857,
#    'liveness': 0.126,
#    'valence': 0.113,
#    'tempo': 137.848,
#    'type': 'audio_features',
#    'id': '1uRxyAup7OYrlh2SHJb80N',
#    'uri': 'spotify:track:1uRxyAup7OYrlh2SHJb80N',
#    'track_href': 'https://api.spotify.com/v1/tracks/1uRxyAup7OYrlh2SHJb80N',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uRxyAup7OYrlh2SHJb80N',
#    'duration_ms': 384439,
#    'time_signature': 3}],
#  [{'danceability': 0.56,
#    'energy': 0.5,
#    'key': 2,
#    'loudness': -10.829,
#    'mode': 0,
#    'speechiness': 0.0272,
#    'acousticness': 0.668,
#    'instrumentalness': 0.833,
#    'liveness': 0.117,
#    'valence': 0.249,
#    'tempo': 139.174,
#    'type': 'audio_features',
#    'id': '5rIhBK9aaVMck0W2YtOwci',
#    'uri': 'spotify:track:5rIhBK9aaVMck0W2YtOwci',
#    'track_href': 'https://api.spotify.com/v1/tracks/5rIhBK9aaVMck0W2YtOwci',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rIhBK9aaVMck0W2YtOwci',
#    'duration_ms': 281011,
#    'time_signature': 4}],
#  [{'danceability': 0.561,
#    'energy': 0.282,
#    'key': 0,
#    'loudness': -13.241,
#    'mode': 1,
#    'speechiness': 0.0286,
#    'acousticness': 0.868,
#    'instrumentalness': 0.529,
#    'liveness': 0.11,
#    'valence': 0.158,
#    'tempo': 112.011,
#    'type': 'audio_features',
#    'id': '1kBGeOp1CDUHVdbK4ergqo',
#    'uri': 'spotify:track:1kBGeOp1CDUHVdbK4ergqo',
#    'track_href': 'https://api.spotify.com/v1/tracks/1kBGeOp1CDUHVdbK4ergqo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1kBGeOp1CDUHVdbK4ergqo',
#    'duration_ms': 224698,
#    'time_signature': 1}],
#  [{'danceability': 0.426,
#    'energy': 0.661,
#    'key': 0,
#    'loudness': -9.877,
#    'mode': 1,
#    'speechiness': 0.0503,
#    'acousticness': 0.353,
#    'instrumentalness': 0.94,
#    'liveness': 0.619,
#    'valence': 0.178,
#    'tempo': 151.191,
#    'type': 'audio_features',
#    'id': '4CzTgOmc3Sdm4EgKQWzjQl',
#    'uri': 'spotify:track:4CzTgOmc3Sdm4EgKQWzjQl',
#    'track_href': 'https://api.spotify.com/v1/tracks/4CzTgOmc3Sdm4EgKQWzjQl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CzTgOmc3Sdm4EgKQWzjQl',
#    'duration_ms': 367349,
#    'time_signature': 3}],
#  [{'danceability': 0.218,
#    'energy': 0.11,
#    'key': 8,
#    'loudness': -15.721,
#    'mode': 1,
#    'speechiness': 0.0344,
#    'acousticness': 0.955,
#    'instrumentalness': 0.557,
#    'liveness': 0.138,
#    'valence': 0.0616,
#    'tempo': 105.113,
#    'type': 'audio_features',
#    'id': '0eZN5WsQfmNFICHuw59Zfz',
#    'uri': 'spotify:track:0eZN5WsQfmNFICHuw59Zfz',
#    'track_href': 'https://api.spotify.com/v1/tracks/0eZN5WsQfmNFICHuw59Zfz',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eZN5WsQfmNFICHuw59Zfz',
#    'duration_ms': 172936,
#    'time_signature': 4}],
#  [{'danceability': 0.692,
#    'energy': 0.458,
#    'key': 11,
#    'loudness': -9.461,
#    'mode': 0,
#    'speechiness': 0.0403,
#    'acousticness': 0.0635,
#    'instrumentalness': 0.516,
#    'liveness': 0.136,
#    'valence': 0.35,
#    'tempo': 150.695,
#    'type': 'audio_features',
#    'id': '3LhtqibvTtjOUrzKs7Vsz1',
#    'uri': 'spotify:track:3LhtqibvTtjOUrzKs7Vsz1',
#    'track_href': 'https://api.spotify.com/v1/tracks/3LhtqibvTtjOUrzKs7Vsz1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LhtqibvTtjOUrzKs7Vsz1',
#    'duration_ms': 266644,
#    'time_signature': 4}],
#  [{'danceability': 0.282,
#    'energy': 0.372,
#    'key': 5,
#    'loudness': -9.771,
#    'mode': 1,
#    'speechiness': 0.0316,
#    'acousticness': 0.652,
#    'instrumentalness': 0.416,
#    'liveness': 0.0754,
#    'valence': 0.0552,
#    'tempo': 105.215,
#    'type': 'audio_features',
#    'id': '6f6pEjgfTtuRROmJ4a7Gf3',
#    'uri': 'spotify:track:6f6pEjgfTtuRROmJ4a7Gf3',
#    'track_href': 'https://api.spotify.com/v1/tracks/6f6pEjgfTtuRROmJ4a7Gf3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6f6pEjgfTtuRROmJ4a7Gf3',
#    'duration_ms': 345887,
#    'time_signature': 3}],
#  [{'danceability': 0.479,
#    'energy': 0.407,
#    'key': 1,
#    'loudness': -12.428,
#    'mode': 0,
#    'speechiness': 0.0346,
#    'acousticness': 0.912,
#    'instrumentalness': 0.401,
#    'liveness': 0.11,
#    'valence': 0.338,
#    'tempo': 91.91,
#    'type': 'audio_features',
#    'id': '4eruRiSfDY1jdT03hjyi0i',
#    'uri': 'spotify:track:4eruRiSfDY1jdT03hjyi0i',
#    'track_href': 'https://api.spotify.com/v1/tracks/4eruRiSfDY1jdT03hjyi0i',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eruRiSfDY1jdT03hjyi0i',
#    'duration_ms': 306581,
#    'time_signature': 4}],
#  [{'danceability': 0.336,
#    'energy': 0.435,
#    'key': 8,
#    'loudness': -10.944,
#    'mode': 0,
#    'speechiness': 0.0305,
#    'acousticness': 0.73,
#    'instrumentalness': 0.797,
#    'liveness': 0.106,
#    'valence': 0.0507,
#    'tempo': 88.205,
#    'type': 'audio_features',
#    'id': '3cual6JOG286qZJmCxKRAT',
#    'uri': 'spotify:track:3cual6JOG286qZJmCxKRAT',
#    'track_href': 'https://api.spotify.com/v1/tracks/3cual6JOG286qZJmCxKRAT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3cual6JOG286qZJmCxKRAT',
#    'duration_ms': 303689,
#    'time_signature': 4}],
#  [{'danceability': 0.282,
#    'energy': 0.132,
#    'key': 0,
#    'loudness': -15.569,
#    'mode': 1,
#    'speechiness': 0.0375,
#    'acousticness': 0.938,
#    'instrumentalness': 0.104,
#    'liveness': 0.1,
#    'valence': 0.0379,
#    'tempo': 136.186,
#    'type': 'audio_features',
#    'id': '01ZpFhrMMqKPVCwyqXneVp',
#    'uri': 'spotify:track:01ZpFhrMMqKPVCwyqXneVp',
#    'track_href': 'https://api.spotify.com/v1/tracks/01ZpFhrMMqKPVCwyqXneVp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01ZpFhrMMqKPVCwyqXneVp',
#    'duration_ms': 283464,
#    'time_signature': 4}]]

# %%
tracks_objects = []
tracks_audio_features = []

# %%
#get song objects and audio features
for songs in tqdm(song_ids2[2264:]):
    for song in songs:
        if song != 'Spotify features Not found':
            time.sleep(1)
            objects = GetTrackDescription(song)
            tracks_objects.append(objects)
            features = GetTrackInfo(song)
            tracks_audio_features.append(features)
            with open('features_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_audio_features, f)
            with open('object_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_objects, f)
        else:
            tracks_objects.append({'status':'Not found'})
            tracks_audio_features.append({'status':'Not found'})
            with open('features_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_audio_features, f)
            with open('object_spotify.pkl', 'wb') as f:
                pickle.dump(tracks_objects, f)
# Out:
#   0%|          | 0/4248 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 1/4248 [00:04<4:46:39,  4.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 2/4248 [00:08<4:48:16,  4.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 3/4248 [00:10<4:06:55,  3.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 4/4248 [00:14<4:13:38,  3.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 5/4248 [00:16<3:38:15,  3.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 6/4248 [00:20<4:12:48,  3.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 7/4248 [00:25<4:29:00,  3.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 8/4248 [00:29<4:36:43,  3.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 9/4248 [00:33<4:48:36,  4.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 10/4248 [00:38<4:56:31,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 11/4248 [00:42<4:55:34,  4.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 12/4248 [00:46<4:57:17,  4.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 13/4248 [00:52<5:28:17,  4.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 14/4248 [00:54<4:29:50,  3.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 15/4248 [00:59<4:50:29,  4.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 16/4248 [01:03<4:52:28,  4.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 17/4248 [01:07<4:45:26,  4.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 18/4248 [01:10<4:42:55,  4.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 19/4248 [01:12<3:55:24,  3.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 20/4248 [01:14<3:22:13,  2.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 21/4248 [01:18<3:43:22,  3.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 22/4248 [01:23<4:15:06,  3.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 23/4248 [01:27<4:34:34,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 24/4248 [01:31<4:29:17,  3.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 25/4248 [01:36<4:50:00,  4.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 26/4248 [01:39<4:41:56,  4.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 27/4248 [01:43<4:37:05,  3.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 28/4248 [01:47<4:43:41,  4.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 29/4248 [01:51<4:43:40,  4.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 30/4248 [01:53<3:57:36,  3.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 31/4248 [01:55<3:23:38,  2.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 32/4248 [01:59<3:40:21,  3.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 33/4248 [02:02<3:52:56,  3.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 34/4248 [02:07<4:20:09,  3.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 35/4248 [02:11<4:28:28,  3.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 36/4248 [02:15<4:38:17,  3.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 37/4248 [02:22<5:41:39,  4.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 38/4248 [02:26<5:14:26,  4.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 39/4248 [02:30<5:10:57,  4.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 40/4248 [02:35<5:09:17,  4.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 41/4248 [02:38<4:46:35,  4.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 42/4248 [02:43<5:10:37,  4.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 43/4248 [02:47<5:01:36,  4.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 44/4248 [02:52<5:00:38,  4.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 45/4248 [02:56<4:58:54,  4.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 46/4248 [03:00<4:49:35,  4.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 47/4248 [03:03<4:44:54,  4.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 48/4248 [03:07<4:28:06,  3.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 49/4248 [03:11<4:30:45,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 50/4248 [03:16<4:53:02,  4.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 51/4248 [03:20<4:54:41,  4.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 52/4248 [03:24<4:59:11,  4.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 53/4248 [03:29<5:02:39,  4.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 54/4248 [03:33<5:05:29,  4.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 55/4248 [03:35<4:16:55,  3.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 56/4248 [03:39<4:18:05,  3.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 57/4248 [03:44<4:36:37,  3.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 58/4248 [03:48<4:46:27,  4.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 59/4248 [03:53<5:12:13,  4.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 60/4248 [03:57<5:02:25,  4.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 61/4248 [03:59<4:09:46,  3.58s/it]
#   1%|▏         | 62/4248 [04:04<4:29:51,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   1%|▏         | 63/4248 [04:06<3:45:41,  3.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 64/4248 [04:07<3:14:51,  2.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 65/4248 [04:11<3:39:58,  3.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 66/4248 [04:15<3:51:47,  3.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 67/4248 [04:20<4:31:46,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 68/4248 [04:22<3:47:00,  3.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 69/4248 [04:26<4:09:11,  3.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 70/4248 [04:30<4:12:04,  3.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 71/4248 [04:32<3:38:41,  3.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 72/4248 [04:36<3:55:43,  3.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 73/4248 [04:41<4:36:32,  3.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 74/4248 [04:45<4:36:41,  3.98s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-416-9a6494b85499> in <module>
#       5             objects = GetTrackDescription(song)
#       6             tracks_objects.append(objects)
# ----> 7             features = GetTrackInfo(song)
#       8             tracks_audio_features.append(features)
#       9             with open('features_spotify.pkl', 'wb') as f:
#
# <ipython-input-330-4b4ea9016366> in GetTrackInfo(track_ids)
#       3     tracks_info = []
#       4     for track_id in track_ids:
# ----> 5         info = sp.audio_features(track_id)
#       6         tracks_info.append(info)
#       7     return tracks_info
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#    1239         if isinstance(tracks, str):
#    1240             trackid = self._get_id("track", tracks)
# -> 1241             results = self._get("audio-features/?ids=" + trackid)
#    1242         else:
#    1243             tlist = [self._get_id("track", t) for t in tracks]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     205             kwargs.update(args)
#     206
# --> 207         return self._internal_call("GET", url, payload, kwargs)
#     208
#     209     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     167             response = self._session.request(
#     168                 method, url, headers=headers, proxies=self.proxies,
# --> 169                 timeout=self.requests_timeout, **args
#     170             )
#     171
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
#had to stop at song_ids2[2337] due to time constraints

# %%
len(tracks_audio_features)
# Out:
# 2333

# %%
tracks_audio_features[0]
# Out:
# [[{'danceability': 0.79,
#    'energy': 0.599,
#    'key': 7,
#    'loudness': -7.417,
#    'mode': 1,
#    'speechiness': 0.0431,
#    'acousticness': 0.218,
#    'instrumentalness': 0.00257,
#    'liveness': 0.118,
#    'valence': 0.362,
#    'tempo': 109.978,
#    'type': 'audio_features',
#    'id': '2moHnkHTSXBe9KjvPSQJvg',
#    'uri': 'spotify:track:2moHnkHTSXBe9KjvPSQJvg',
#    'track_href': 'https://api.spotify.com/v1/tracks/2moHnkHTSXBe9KjvPSQJvg',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2moHnkHTSXBe9KjvPSQJvg',
#    'duration_ms': 266116,
#    'time_signature': 4}],
#  [{'danceability': 0.57,
#    'energy': 0.339,
#    'key': 2,
#    'loudness': -11.857,
#    'mode': 0,
#    'speechiness': 0.0449,
#    'acousticness': 0.569,
#    'instrumentalness': 0.451,
#    'liveness': 0.126,
#    'valence': 0.442,
#    'tempo': 88.963,
#    'type': 'audio_features',
#    'id': '5ccn0VZg8HQZsZXxGx7UZQ',
#    'uri': 'spotify:track:5ccn0VZg8HQZsZXxGx7UZQ',
#    'track_href': 'https://api.spotify.com/v1/tracks/5ccn0VZg8HQZsZXxGx7UZQ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ccn0VZg8HQZsZXxGx7UZQ',
#    'duration_ms': 245077,
#    'time_signature': 4}],
#  [None],
#  [{'danceability': 0.877,
#    'energy': 0.598,
#    'key': 6,
#    'loudness': -6.292,
#    'mode': 0,
#    'speechiness': 0.0296,
#    'acousticness': 0.353,
#    'instrumentalness': 0.00132,
#    'liveness': 0.38,
#    'valence': 0.671,
#    'tempo': 97.012,
#    'type': 'audio_features',
#    'id': '5ZD0jxyhmdNZ3DwDRXqV5U',
#    'uri': 'spotify:track:5ZD0jxyhmdNZ3DwDRXqV5U',
#    'track_href': 'https://api.spotify.com/v1/tracks/5ZD0jxyhmdNZ3DwDRXqV5U',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZD0jxyhmdNZ3DwDRXqV5U',
#    'duration_ms': 178398,
#    'time_signature': 4}],
#  [{'danceability': 0.564,
#    'energy': 0.391,
#    'key': 7,
#    'loudness': -7.816,
#    'mode': 1,
#    'speechiness': 0.0785,
#    'acousticness': 0.235,
#    'instrumentalness': 5.37e-05,
#    'liveness': 0.11,
#    'valence': 0.419,
#    'tempo': 101.449,
#    'type': 'audio_features',
#    'id': '1y2GDXFvtHPbCkHFYg49Gn',
#    'uri': 'spotify:track:1y2GDXFvtHPbCkHFYg49Gn',
#    'track_href': 'https://api.spotify.com/v1/tracks/1y2GDXFvtHPbCkHFYg49Gn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1y2GDXFvtHPbCkHFYg49Gn',
#    'duration_ms': 187970,
#    'time_signature': 4}],
#  [{'danceability': 0.737,
#    'energy': 0.787,
#    'key': 7,
#    'loudness': -4.587,
#    'mode': 1,
#    'speechiness': 0.0525,
#    'acousticness': 0.121,
#    'instrumentalness': 2.14e-06,
#    'liveness': 0.114,
#    'valence': 0.59,
#    'tempo': 90.014,
#    'type': 'audio_features',
#    'id': '5RdkyZw1KQ1v0EbquUAsx2',
#    'uri': 'spotify:track:5RdkyZw1KQ1v0EbquUAsx2',
#    'track_href': 'https://api.spotify.com/v1/tracks/5RdkyZw1KQ1v0EbquUAsx2',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RdkyZw1KQ1v0EbquUAsx2',
#    'duration_ms': 199413,
#    'time_signature': 4}],
#  [{'danceability': 0.757,
#    'energy': 0.598,
#    'key': 8,
#    'loudness': -7.641,
#    'mode': 0,
#    'speechiness': 0.043,
#    'acousticness': 0.311,
#    'instrumentalness': 0.00205,
#    'liveness': 0.104,
#    'valence': 0.336,
#    'tempo': 100.015,
#    'type': 'audio_features',
#    'id': '6H5PpiwCO61mWgWEgDb7ZU',
#    'uri': 'spotify:track:6H5PpiwCO61mWgWEgDb7ZU',
#    'track_href': 'https://api.spotify.com/v1/tracks/6H5PpiwCO61mWgWEgDb7ZU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6H5PpiwCO61mWgWEgDb7ZU',
#    'duration_ms': 219073,
#    'time_signature': 4}],
#  [{'danceability': 0.717,
#    'energy': 0.86,
#    'key': 0,
#    'loudness': -5.714,
#    'mode': 1,
#    'speechiness': 0.0336,
#    'acousticness': 0.0613,
#    'instrumentalness': 0.000583,
#    'liveness': 0.224,
#    'valence': 0.524,
#    'tempo': 120.011,
#    'type': 'audio_features',
#    'id': '6rhz5IdIWfnU30MFuiL7Di',
#    'uri': 'spotify:track:6rhz5IdIWfnU30MFuiL7Di',
#    'track_href': 'https://api.spotify.com/v1/tracks/6rhz5IdIWfnU30MFuiL7Di',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rhz5IdIWfnU30MFuiL7Di',
#    'duration_ms': 214959,
#    'time_signature': 4}],
#  [{'danceability': 0.643,
#    'energy': 0.633,
#    'key': 11,
#    'loudness': -9.368,
#    'mode': 0,
#    'speechiness': 0.0473,
#    'acousticness': 0.0942,
#    'instrumentalness': 0.00477,
#    'liveness': 0.248,
#    'valence': 0.382,
#    'tempo': 98.984,
#    'type': 'audio_features',
#    'id': '7DCKlgZuZcljJSlvt8vsZa',
#    'uri': 'spotify:track:7DCKlgZuZcljJSlvt8vsZa',
#    'track_href': 'https://api.spotify.com/v1/tracks/7DCKlgZuZcljJSlvt8vsZa',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DCKlgZuZcljJSlvt8vsZa',
#    'duration_ms': 321045,
#    'time_signature': 4}],
#  [{'danceability': 0.764,
#    'energy': 0.339,
#    'key': 0,
#    'loudness': -12.195,
#    'mode': 1,
#    'speechiness': 0.047,
#    'acousticness': 0.567,
#    'instrumentalness': 0.0205,
#    'liveness': 0.0987,
#    'valence': 0.402,
#    'tempo': 143.993,
#    'type': 'audio_features',
#    'id': '2NYPCh5sEiXsNhvNIjYIhA',
#    'uri': 'spotify:track:2NYPCh5sEiXsNhvNIjYIhA',
#    'track_href': 'https://api.spotify.com/v1/tracks/2NYPCh5sEiXsNhvNIjYIhA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NYPCh5sEiXsNhvNIjYIhA',
#    'duration_ms': 263400,
#    'time_signature': 4}],
#  [{'danceability': 0.79,
#    'energy': 0.475,
#    'key': 0,
#    'loudness': -6.787,
#    'mode': 1,
#    'speechiness': 0.0585,
#    'acousticness': 0.0772,
#    'instrumentalness': 7.58e-05,
#    'liveness': 0.125,
#    'valence': 0.827,
#    'tempo': 95.003,
#    'type': 'audio_features',
#    'id': '4LdTaU7Xqml2idOJjy96xR',
#    'uri': 'spotify:track:4LdTaU7Xqml2idOJjy96xR',
#    'track_href': 'https://api.spotify.com/v1/tracks/4LdTaU7Xqml2idOJjy96xR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LdTaU7Xqml2idOJjy96xR',
#    'duration_ms': 187086,
#    'time_signature': 4}],
#  [{'danceability': 0.813,
#    'energy': 0.733,
#    'key': 0,
#    'loudness': -8.887,
#    'mode': 1,
#    'speechiness': 0.0421,
#    'acousticness': 0.236,
#    'instrumentalness': 0.231,
#    'liveness': 0.137,
#    'valence': 0.896,
#    'tempo': 97.045,
#    'type': 'audio_features',
#    'id': '1AQx5E3Qspd6Ep7dJc5JCN',
#    'uri': 'spotify:track:1AQx5E3Qspd6Ep7dJc5JCN',
#    'track_href': 'https://api.spotify.com/v1/tracks/1AQx5E3Qspd6Ep7dJc5JCN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AQx5E3Qspd6Ep7dJc5JCN',
#    'duration_ms': 165574,
#    'time_signature': 4}],
#  [{'danceability': 0.76,
#    'energy': 0.738,
#    'key': 10,
#    'loudness': -7.24,
#    'mode': 0,
#    'speechiness': 0.0587,
#    'acousticness': 0.0698,
#    'instrumentalness': 0.0473,
#    'liveness': 0.0518,
#    'valence': 0.878,
#    'tempo': 126.015,
#    'type': 'audio_features',
#    'id': '0XRFBnCTSfl0rGVKgY2zH7',
#    'uri': 'spotify:track:0XRFBnCTSfl0rGVKgY2zH7',
#    'track_href': 'https://api.spotify.com/v1/tracks/0XRFBnCTSfl0rGVKgY2zH7',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XRFBnCTSfl0rGVKgY2zH7',
#    'duration_ms': 254322,
#    'time_signature': 4}],
#  [{'danceability': 0.828,
#    'energy': 0.513,
#    'key': 8,
#    'loudness': -7.368,
#    'mode': 0,
#    'speechiness': 0.046,
#    'acousticness': 0.374,
#    'instrumentalness': 0.03,
#    'liveness': 0.0647,
#    'valence': 0.879,
#    'tempo': 114.982,
#    'type': 'audio_features',
#    'id': '7bIAAD7Sl8fWW7nKSDDpNt',
#    'uri': 'spotify:track:7bIAAD7Sl8fWW7nKSDDpNt',
#    'track_href': 'https://api.spotify.com/v1/tracks/7bIAAD7Sl8fWW7nKSDDpNt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7bIAAD7Sl8fWW7nKSDDpNt',
#    'duration_ms': 224095,
#    'time_signature': 4}],
#  [{'danceability': 0.579,
#    'energy': 0.553,
#    'key': 11,
#    'loudness': -9.06,
#    'mode': 0,
#    'speechiness': 0.0361,
#    'acousticness': 0.255,
#    'instrumentalness': 0.0711,
#    'liveness': 0.107,
#    'valence': 0.35,
#    'tempo': 78.483,
#    'type': 'audio_features',
#    'id': '3fV4kgcQzh2aLGSJbSAtoV',
#    'uri': 'spotify:track:3fV4kgcQzh2aLGSJbSAtoV',
#    'track_href': 'https://api.spotify.com/v1/tracks/3fV4kgcQzh2aLGSJbSAtoV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3fV4kgcQzh2aLGSJbSAtoV',
#    'duration_ms': 212895,
#    'time_signature': 4}]]

# %%
len(tracks_objects)
# Out:
# 2334

# %%
tracks_objects[0]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 266115,
#   'explicit': True,
#   'external_ids': {'isrc': 'USAT22000079'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2moHnkHTSXBe9KjvPSQJvg'},
#   'href': 'https://api.spotify.com/v1/tracks/2moHnkHTSXBe9KjvPSQJvg',
#   'id': '2moHnkHTSXBe9KjvPSQJvg',
#   'is_local': False,
#   'name': 'Simmer',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0257f7fba691830fc450dcd77f42d7f7398d2c40?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2moHnkHTSXBe9KjvPSQJvg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 245076,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000080'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5ccn0VZg8HQZsZXxGx7UZQ'},
#   'href': 'https://api.spotify.com/v1/tracks/5ccn0VZg8HQZsZXxGx7UZQ',
#   'id': '5ccn0VZg8HQZsZXxGx7UZQ',
#   'is_local': False,
#   'name': 'Leave It Alone',
#   'popularity': 61,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c9477e7c83ce047fd5547f994cf2874526173c15?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:5ccn0VZg8HQZsZXxGx7UZQ'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 211834,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000081'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/48pL4zB6KXWPvd7Ln33ENy'},
#   'href': 'https://api.spotify.com/v1/tracks/48pL4zB6KXWPvd7Ln33ENy',
#   'id': '48pL4zB6KXWPvd7Ln33ENy',
#   'is_local': False,
#   'name': 'Cinnamon',
#   'popularity': 61,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b3b14844796c86e7faff7c6b8daf5e014446a329?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:48pL4zB6KXWPvd7Ln33ENy'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 178398,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000082'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5ZD0jxyhmdNZ3DwDRXqV5U'},
#   'href': 'https://api.spotify.com/v1/tracks/5ZD0jxyhmdNZ3DwDRXqV5U',
#   'id': '5ZD0jxyhmdNZ3DwDRXqV5U',
#   'is_local': False,
#   'name': "Creepin'",
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4596beca37e6e33dfc8e1fd2083557ec32f2071b?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5ZD0jxyhmdNZ3DwDRXqV5U'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 187969,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000083'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1y2GDXFvtHPbCkHFYg49Gn'},
#   'href': 'https://api.spotify.com/v1/tracks/1y2GDXFvtHPbCkHFYg49Gn',
#   'id': '1y2GDXFvtHPbCkHFYg49Gn',
#   'is_local': False,
#   'name': 'Sudden Desire',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a1b5e4c23045d2d3388e01e9224397b4f5ca8732?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:1y2GDXFvtHPbCkHFYg49Gn'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 2,
#   'duration_ms': 199412,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000847'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5RdkyZw1KQ1v0EbquUAsx2'},
#   'href': 'https://api.spotify.com/v1/tracks/5RdkyZw1KQ1v0EbquUAsx2',
#   'id': '5RdkyZw1KQ1v0EbquUAsx2',
#   'is_local': False,
#   'name': 'Dead Horse',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/d05d82984cc650a06a124ed0a1c52e554c293e4c?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5RdkyZw1KQ1v0EbquUAsx2'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 2,
#   'duration_ms': 219073,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000848'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6H5PpiwCO61mWgWEgDb7ZU'},
#   'href': 'https://api.spotify.com/v1/tracks/6H5PpiwCO61mWgWEgDb7ZU',
#   'id': '6H5PpiwCO61mWgWEgDb7ZU',
#   'is_local': False,
#   'name': 'My Friend',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8df672f88cd58c665be90bebadb2529bc6ae5081?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:6H5PpiwCO61mWgWEgDb7ZU'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 2,
#   'duration_ms': 214959,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000849'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6rhz5IdIWfnU30MFuiL7Di'},
#   'href': 'https://api.spotify.com/v1/tracks/6rhz5IdIWfnU30MFuiL7Di',
#   'id': '6rhz5IdIWfnU30MFuiL7Di',
#   'is_local': False,
#   'name': 'Over Yet',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5ffda09af5e551f3598b6303df1e6bd9912a88e4?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:6rhz5IdIWfnU30MFuiL7Di'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 2,
#   'duration_ms': 321044,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000850'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7DCKlgZuZcljJSlvt8vsZa'},
#   'href': 'https://api.spotify.com/v1/tracks/7DCKlgZuZcljJSlvt8vsZa',
#   'id': '7DCKlgZuZcljJSlvt8vsZa',
#   'is_local': False,
#   'name': 'Roses/Lotus/Violet/Iris',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/17273d24d769af12452dd1fc630ec309dd87ce99?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:7DCKlgZuZcljJSlvt8vsZa'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 2,
#   'duration_ms': 263400,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000851'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2NYPCh5sEiXsNhvNIjYIhA'},
#   'href': 'https://api.spotify.com/v1/tracks/2NYPCh5sEiXsNhvNIjYIhA',
#   'id': '2NYPCh5sEiXsNhvNIjYIhA',
#   'is_local': False,
#   'name': 'Why We Ever',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/87305391bc5f51c525042bc8e45012f145afe34c?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:2NYPCh5sEiXsNhvNIjYIhA'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 3,
#   'duration_ms': 187086,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000852'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4LdTaU7Xqml2idOJjy96xR'},
#   'href': 'https://api.spotify.com/v1/tracks/4LdTaU7Xqml2idOJjy96xR',
#   'id': '4LdTaU7Xqml2idOJjy96xR',
#   'is_local': False,
#   'name': 'Pure Love',
#   'popularity': 65,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5e27ddecd75ae7a4ee371bce619ebb196a4ce014?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4LdTaU7Xqml2idOJjy96xR'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 3,
#   'duration_ms': 165574,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000853'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1AQx5E3Qspd6Ep7dJc5JCN'},
#   'href': 'https://api.spotify.com/v1/tracks/1AQx5E3Qspd6Ep7dJc5JCN',
#   'id': '1AQx5E3Qspd6Ep7dJc5JCN',
#   'is_local': False,
#   'name': 'Taken',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e18c9408cd37c81bbee5c6e7c08b603968db9398?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1AQx5E3Qspd6Ep7dJc5JCN'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 3,
#   'duration_ms': 254321,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000854'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0XRFBnCTSfl0rGVKgY2zH7'},
#   'href': 'https://api.spotify.com/v1/tracks/0XRFBnCTSfl0rGVKgY2zH7',
#   'id': '0XRFBnCTSfl0rGVKgY2zH7',
#   'is_local': False,
#   'name': 'Sugar On The Rim',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/37db4ca46b7718b7d54470d84ffe2309c2582fef?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:0XRFBnCTSfl0rGVKgY2zH7'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 3,
#   'duration_ms': 224094,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000855'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7bIAAD7Sl8fWW7nKSDDpNt'},
#   'href': 'https://api.spotify.com/v1/tracks/7bIAAD7Sl8fWW7nKSDDpNt',
#   'id': '7bIAAD7Sl8fWW7nKSDDpNt',
#   'is_local': False,
#   'name': 'Watch Me While I Bloom',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3eb9684e1494415102f58d5297cb2090e6a3ca88?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:7bIAAD7Sl8fWW7nKSDDpNt'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#      'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#      'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#      'name': 'Hayley Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4HXpQ5KQBVWN25ltjnX7xa'},
#    'href': 'https://api.spotify.com/v1/albums/4HXpQ5KQBVWN25ltjnX7xa',
#    'id': '4HXpQ5KQBVWN25ltjnX7xa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273896e2483613a566bcb00d324',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02896e2483613a566bcb00d324',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851896e2483613a566bcb00d324',
#      'width': 64}],
#    'name': 'Petals For Armor',
#    'release_date': '2020-05-08',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:4HXpQ5KQBVWN25ltjnX7xa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Rx1JKzBrSzoKQtmbVmBnM'},
#     'href': 'https://api.spotify.com/v1/artists/6Rx1JKzBrSzoKQtmbVmBnM',
#     'id': '6Rx1JKzBrSzoKQtmbVmBnM',
#     'name': 'Hayley Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Rx1JKzBrSzoKQtmbVmBnM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 3,
#   'duration_ms': 212894,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT22000856'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3fV4kgcQzh2aLGSJbSAtoV'},
#   'href': 'https://api.spotify.com/v1/tracks/3fV4kgcQzh2aLGSJbSAtoV',
#   'id': '3fV4kgcQzh2aLGSJbSAtoV',
#   'is_local': False,
#   'name': 'Crystal Clear',
#   'popularity': 62,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5bd04b0adeba0047a37faef5cf190059457c6c6d?cid=e60fd635aa7d490b9fa4e73768641362',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:3fV4kgcQzh2aLGSJbSAtoV'}]

# %% [markdown]
# ## 5. Store Data

# %%
#function for storing gathered spotify data
def store_track(album_pop, track_descriptions, tracks_info):
    spotify_info = {
        "song_info": track_descriptions,
        "audio_features": tracks_info,
        "album_popularity": album_pop}

    return spotify_info

# %%
#test function
g = store_track(b, d, e)
g
# Out:
# {'song_info': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 220609,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600071'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3pcCifdPTc2BbqmWpEhtUd'},
#    'href': 'https://api.spotify.com/v1/tracks/3pcCifdPTc2BbqmWpEhtUd',
#    'id': '3pcCifdPTc2BbqmWpEhtUd',
#    'is_local': False,
#    'name': 'Burn the Witch',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c5b0b198ee3f045960106e9957550e4610555d7d?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3pcCifdPTc2BbqmWpEhtUd'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 384438,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600072'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1uRxyAup7OYrlh2SHJb80N'},
#    'href': 'https://api.spotify.com/v1/tracks/1uRxyAup7OYrlh2SHJb80N',
#    'id': '1uRxyAup7OYrlh2SHJb80N',
#    'is_local': False,
#    'name': 'Daydreaming',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fbf970f6ee1e7d849de08017d3688406107c751a?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1uRxyAup7OYrlh2SHJb80N'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 281011,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600073'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5rIhBK9aaVMck0W2YtOwci'},
#    'href': 'https://api.spotify.com/v1/tracks/5rIhBK9aaVMck0W2YtOwci',
#    'id': '5rIhBK9aaVMck0W2YtOwci',
#    'is_local': False,
#    'name': 'Decks Dark',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3500e1883855236feda78e798f04b4bffad11d43?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5rIhBK9aaVMck0W2YtOwci'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 224698,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600074'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1kBGeOp1CDUHVdbK4ergqo'},
#    'href': 'https://api.spotify.com/v1/tracks/1kBGeOp1CDUHVdbK4ergqo',
#    'id': '1kBGeOp1CDUHVdbK4ergqo',
#    'is_local': False,
#    'name': 'Desert Island Disk',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0a484b7a356f34f1561f126827edd15f02d4d178?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1kBGeOp1CDUHVdbK4ergqo'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 367348,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600075'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4CzTgOmc3Sdm4EgKQWzjQl'},
#    'href': 'https://api.spotify.com/v1/tracks/4CzTgOmc3Sdm4EgKQWzjQl',
#    'id': '4CzTgOmc3Sdm4EgKQWzjQl',
#    'is_local': False,
#    'name': 'Ful Stop',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7b544b63c8c8aa645a3ca9dcbaf4d5ae262fcb61?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4CzTgOmc3Sdm4EgKQWzjQl'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 172935,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600076'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0eZN5WsQfmNFICHuw59Zfz'},
#    'href': 'https://api.spotify.com/v1/tracks/0eZN5WsQfmNFICHuw59Zfz',
#    'id': '0eZN5WsQfmNFICHuw59Zfz',
#    'is_local': False,
#    'name': 'Glass Eyes',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4619aaddaa93174494952f25319cbc85b15b3a04?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0eZN5WsQfmNFICHuw59Zfz'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 266643,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600077'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3LhtqibvTtjOUrzKs7Vsz1'},
#    'href': 'https://api.spotify.com/v1/tracks/3LhtqibvTtjOUrzKs7Vsz1',
#    'id': '3LhtqibvTtjOUrzKs7Vsz1',
#    'is_local': False,
#    'name': 'Identikit',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/00db1006a1278a6ae48e4c5688fc51f054caa2f3?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3LhtqibvTtjOUrzKs7Vsz1'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 345886,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600078'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6f6pEjgfTtuRROmJ4a7Gf3'},
#    'href': 'https://api.spotify.com/v1/tracks/6f6pEjgfTtuRROmJ4a7Gf3',
#    'id': '6f6pEjgfTtuRROmJ4a7Gf3',
#    'is_local': False,
#    'name': 'The Numbers',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/27702a4de95e61186bbcbe17877eaa75bfc0ba1b?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:6f6pEjgfTtuRROmJ4a7Gf3'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 306581,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600079'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4eruRiSfDY1jdT03hjyi0i'},
#    'href': 'https://api.spotify.com/v1/tracks/4eruRiSfDY1jdT03hjyi0i',
#    'id': '4eruRiSfDY1jdT03hjyi0i',
#    'is_local': False,
#    'name': 'Present Tense',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/587a67dfe955b5582d12e252ec648b98b097001e?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4eruRiSfDY1jdT03hjyi0i'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 303688,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600080'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3cual6JOG286qZJmCxKRAT'},
#    'href': 'https://api.spotify.com/v1/tracks/3cual6JOG286qZJmCxKRAT',
#    'id': '3cual6JOG286qZJmCxKRAT',
#    'is_local': False,
#    'name': 'Tinker Tailor Soldier Sailor Rich Man Poor Man Beggar Man Thief',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/28cb214a84754e03d94c5821ad101b901e625b55?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:3cual6JOG286qZJmCxKRAT'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vuykQgDLUCiZ7YggIpLM9'},
#     'href': 'https://api.spotify.com/v1/albums/6vuykQgDLUCiZ7YggIpLM9',
#     'id': '6vuykQgDLUCiZ7YggIpLM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730365011d800890bd210dd043',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020365011d800890bd210dd043',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510365011d800890bd210dd043',
#       'width': 64}],
#     'name': 'A Moon Shaped Pool',
#     'release_date': '2016-05-08',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6vuykQgDLUCiZ7YggIpLM9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 283463,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1600081'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/01ZpFhrMMqKPVCwyqXneVp'},
#    'href': 'https://api.spotify.com/v1/tracks/01ZpFhrMMqKPVCwyqXneVp',
#    'id': '01ZpFhrMMqKPVCwyqXneVp',
#    'is_local': False,
#    'name': 'True Love Waits',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4074ab8ea2a8bb98e29a6a9a7b115c7ca15c0272?cid=e60fd635aa7d490b9fa4e73768641362',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:01ZpFhrMMqKPVCwyqXneVp'}],
#  'audio_features': [[{'danceability': 0.541,
#     'energy': 0.847,
#     'key': 11,
#     'loudness': -6.52,
#     'mode': 1,
#     'speechiness': 0.0297,
#     'acousticness': 0.303,
#     'instrumentalness': 0.271,
#     'liveness': 0.109,
#     'valence': 0.62,
#     'tempo': 148.937,
#     'type': 'audio_features',
#     'id': '3pcCifdPTc2BbqmWpEhtUd',
#     'uri': 'spotify:track:3pcCifdPTc2BbqmWpEhtUd',
#     'track_href': 'https://api.spotify.com/v1/tracks/3pcCifdPTc2BbqmWpEhtUd',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pcCifdPTc2BbqmWpEhtUd',
#     'duration_ms': 220609,
#     'time_signature': 4}],
#   [{'danceability': 0.299,
#     'energy': 0.263,
#     'key': 9,
#     'loudness': -13.207,
#     'mode': 0,
#     'speechiness': 0.0323,
#     'acousticness': 0.968,
#     'instrumentalness': 0.857,
#     'liveness': 0.126,
#     'valence': 0.113,
#     'tempo': 137.848,
#     'type': 'audio_features',
#     'id': '1uRxyAup7OYrlh2SHJb80N',
#     'uri': 'spotify:track:1uRxyAup7OYrlh2SHJb80N',
#     'track_href': 'https://api.spotify.com/v1/tracks/1uRxyAup7OYrlh2SHJb80N',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uRxyAup7OYrlh2SHJb80N',
#     'duration_ms': 384439,
#     'time_signature': 3}],
#   [{'danceability': 0.56,
#     'energy': 0.5,
#     'key': 2,
#     'loudness': -10.829,
#     'mode': 0,
#     'speechiness': 0.0272,
#     'acousticness': 0.668,
#     'instrumentalness': 0.833,
#     'liveness': 0.117,
#     'valence': 0.249,
#     'tempo': 139.174,
#     'type': 'audio_features',
#     'id': '5rIhBK9aaVMck0W2YtOwci',
#     'uri': 'spotify:track:5rIhBK9aaVMck0W2YtOwci',
#     'track_href': 'https://api.spotify.com/v1/tracks/5rIhBK9aaVMck0W2YtOwci',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rIhBK9aaVMck0W2YtOwci',
#     'duration_ms': 281011,
#     'time_signature': 4}],
#   [{'danceability': 0.561,
#     'energy': 0.282,
#     'key': 0,
#     'loudness': -13.241,
#     'mode': 1,
#     'speechiness': 0.0286,
#     'acousticness': 0.868,
#     'instrumentalness': 0.529,
#     'liveness': 0.11,
#     'valence': 0.158,
#     'tempo': 112.011,
#     'type': 'audio_features',
#     'id': '1kBGeOp1CDUHVdbK4ergqo',
#     'uri': 'spotify:track:1kBGeOp1CDUHVdbK4ergqo',
#     'track_href': 'https://api.spotify.com/v1/tracks/1kBGeOp1CDUHVdbK4ergqo',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1kBGeOp1CDUHVdbK4ergqo',
#     'duration_ms': 224698,
#     'time_signature': 1}],
#   [{'danceability': 0.426,
#     'energy': 0.661,
#     'key': 0,
#     'loudness': -9.877,
#     'mode': 1,
#     'speechiness': 0.0503,
#     'acousticness': 0.353,
#     'instrumentalness': 0.94,
#     'liveness': 0.619,
#     'valence': 0.178,
#     'tempo': 151.191,
#     'type': 'audio_features',
#     'id': '4CzTgOmc3Sdm4EgKQWzjQl',
#     'uri': 'spotify:track:4CzTgOmc3Sdm4EgKQWzjQl',
#     'track_href': 'https://api.spotify.com/v1/tracks/4CzTgOmc3Sdm4EgKQWzjQl',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CzTgOmc3Sdm4EgKQWzjQl',
#     'duration_ms': 367349,
#     'time_signature': 3}],
#   [{'danceability': 0.218,
#     'energy': 0.11,
#     'key': 8,
#     'loudness': -15.721,
#     'mode': 1,
#     'speechiness': 0.0344,
#     'acousticness': 0.955,
#     'instrumentalness': 0.557,
#     'liveness': 0.138,
#     'valence': 0.0616,
#     'tempo': 105.113,
#     'type': 'audio_features',
#     'id': '0eZN5WsQfmNFICHuw59Zfz',
#     'uri': 'spotify:track:0eZN5WsQfmNFICHuw59Zfz',
#     'track_href': 'https://api.spotify.com/v1/tracks/0eZN5WsQfmNFICHuw59Zfz',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eZN5WsQfmNFICHuw59Zfz',
#     'duration_ms': 172936,
#     'time_signature': 4}],
#   [{'danceability': 0.692,
#     'energy': 0.458,
#     'key': 11,
#     'loudness': -9.461,
#     'mode': 0,
#     'speechiness': 0.0403,
#     'acousticness': 0.0635,
#     'instrumentalness': 0.516,
#     'liveness': 0.136,
#     'valence': 0.35,
#     'tempo': 150.695,
#     'type': 'audio_features',
#     'id': '3LhtqibvTtjOUrzKs7Vsz1',
#     'uri': 'spotify:track:3LhtqibvTtjOUrzKs7Vsz1',
#     'track_href': 'https://api.spotify.com/v1/tracks/3LhtqibvTtjOUrzKs7Vsz1',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LhtqibvTtjOUrzKs7Vsz1',
#     'duration_ms': 266644,
#     'time_signature': 4}],
#   [{'danceability': 0.282,
#     'energy': 0.372,
#     'key': 5,
#     'loudness': -9.771,
#     'mode': 1,
#     'speechiness': 0.0316,
#     'acousticness': 0.652,
#     'instrumentalness': 0.416,
#     'liveness': 0.0754,
#     'valence': 0.0552,
#     'tempo': 105.215,
#     'type': 'audio_features',
#     'id': '6f6pEjgfTtuRROmJ4a7Gf3',
#     'uri': 'spotify:track:6f6pEjgfTtuRROmJ4a7Gf3',
#     'track_href': 'https://api.spotify.com/v1/tracks/6f6pEjgfTtuRROmJ4a7Gf3',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6f6pEjgfTtuRROmJ4a7Gf3',
#     'duration_ms': 345887,
#     'time_signature': 3}],
#   [{'danceability': 0.479,
#     'energy': 0.407,
#     'key': 1,
#     'loudness': -12.428,
#     'mode': 0,
#     'speechiness': 0.0346,
#     'acousticness': 0.912,
#     'instrumentalness': 0.401,
#     'liveness': 0.11,
#     'valence': 0.338,
#     'tempo': 91.91,
#     'type': 'audio_features',
#     'id': '4eruRiSfDY1jdT03hjyi0i',
#     'uri': 'spotify:track:4eruRiSfDY1jdT03hjyi0i',
#     'track_href': 'https://api.spotify.com/v1/tracks/4eruRiSfDY1jdT03hjyi0i',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eruRiSfDY1jdT03hjyi0i',
#     'duration_ms': 306581,
#     'time_signature': 4}],
#   [{'danceability': 0.336,
#     'energy': 0.435,
#     'key': 8,
#     'loudness': -10.944,
#     'mode': 0,
#     'speechiness': 0.0305,
#     'acousticness': 0.73,
#     'instrumentalness': 0.797,
#     'liveness': 0.106,
#     'valence': 0.0507,
#     'tempo': 88.205,
#     'type': 'audio_features',
#     'id': '3cual6JOG286qZJmCxKRAT',
#     'uri': 'spotify:track:3cual6JOG286qZJmCxKRAT',
#     'track_href': 'https://api.spotify.com/v1/tracks/3cual6JOG286qZJmCxKRAT',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3cual6JOG286qZJmCxKRAT',
#     'duration_ms': 303689,
#     'time_signature': 4}],
#   [{'danceability': 0.282,
#     'energy': 0.132,
#     'key': 0,
#     'loudness': -15.569,
#     'mode': 1,
#     'speechiness': 0.0375,
#     'acousticness': 0.938,
#     'instrumentalness': 0.104,
#     'liveness': 0.1,
#     'valence': 0.0379,
#     'tempo': 136.186,
#     'type': 'audio_features',
#     'id': '01ZpFhrMMqKPVCwyqXneVp',
#     'uri': 'spotify:track:01ZpFhrMMqKPVCwyqXneVp',
#     'track_href': 'https://api.spotify.com/v1/tracks/01ZpFhrMMqKPVCwyqXneVp',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01ZpFhrMMqKPVCwyqXneVp',
#     'duration_ms': 283464,
#     'time_signature': 4}]],
#  'album_popularity': 66}

# %%
spotify_data = store_track(album_pop2_name, tracks_objects, tracks_audio_features)

# %%
spotify_data.items()[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-431-13060ccc3133> in <module>
# ----> 1 spotify_data.items()[5]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
spotify_df = pd.DataFrame(columns=[
    'song_name',
    'duration_ms',
    'album_popularity',
    'num_markets',
    'album_name',
    'is_explicit',
    'track_number',
    'release_date',
    'artist',
    'danceability',
    'energy',
    'key',
    'loudness',
    'mode',
    'speechiness',
    'acousticness',
    'instrumentalness',
    'liveness',
    'valence',
    'tempo',
    'time_signature',])

for k, v in zip(
    g.get('song_info'), 
    g.get('audio_features')):
    #,
    #g.get('album_popularity'))
    for track_info, track_features in zip(
        k.get('song_info'),
        v
        ):
        y = {
            'song_name': track_info['name'],
            'duration_ms': track_info['duration_ms'],
            'popularity': album_pop,
            'num_markets': len(track_info['available_markets']),
            'album_name': track_info['album']['name'],
            'is_explicit': track_info['explicit'],
            'track_number': track_info['track_number'],
            'release_date': track_info['album']['release_date'],
            'artist': track_info['artists'][0]['name'],
            'danceability': tracks_features['danceability'],
            'energy': tracks_features['energy'],
            'key': tracks_features['key'],
            'loudness': tracks_features['loudness'],
            'mode': tracks_features['mode'],
            'speechiness': tracks_features['speechiness'],
            'acousticness': tracks_features['acousticness'],
            'instrumentalness': tracks_features['instrumentalness'],
            'liveness': tracks_features['liveness'],
            'valence': tracks_features['valence'],
            'tempo': tracks_features['tempo'],
            'time_signature': tracks_features['time_signature'],
        }
        df = df.append(y, ignore_index=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-232-061af29bec75> in <module>
#      24 for k, v in zip(
#      25     g.get('song_info'),
# ---> 26     g.get('audio_features')):
#      27     #,
#      28     #g.get('album_popularity'))
#
# TypeError: zip argument #2 must support iteration
